# %%
# !nvidia-smi
# Out:
# Mon May 23 11:41:08 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 511.69       Driver Version: 511.69       CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   66C    P8     4W /  N/A |    386MiB /  4096MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1824    C+G                                   N/A      |
# |    0   N/A  N/A     26120    C+G   ...llMobileConnectClient.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']=''


# In[3]:


import time
import sys
import os
import random
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch import optim
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from torchvision import transforms, utils
import numpy as np
from tqdm.auto import tqdm
from collections import Counter
from matplotlib import pyplot as plt
from collections import OrderedDict

SEED = 0
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
import pandas as pd

# %%
path_dataset = os.path.join('..','dataset','thai2rom')
test_filepaths = os.path.join(path_dataset,'test.tsv')
test_df = pd.read_csv(test_filepaths,sep="\t")

# %%
def load_data(data_path):
    input_texts = [str(i) for i in list(data_path['roman'])]
    target_texts = [str(i) for i in list(data_path['word'])]
    return input_texts, target_texts

# %%
test_input_texts, test_target_texts = load_data(test_df)

# %%
# Define special characters
UNK_token = '<UNK>'
PAD_token = '<PAD>'
START_token = '<start>'
END_token = '<end>'
MAX_LENGTH = 25

class Language:
    def __init__(self, name, is_input=False):
        self.name = name
        self.characters = set()
        self.n_chars = 0
        self.char2index = {}
        self.index2char = {}

        if is_input == True:
            self.index2char = { 0: PAD_token, 1: UNK_token, 2: START_token, 3: END_token }
            self.char2index = { ch:i for i, ch in self.index2char.items() } #reverse dictionary
            self.n_chars = 4
        else:
            self.index2char = { 0: PAD_token, 1: START_token, 2: END_token }
            self.char2index = { ch:i for i, ch in self.index2char.items() } #reverse dictionary
            self.n_chars = 3

    def addText(self, text):
        for character in text:
            self.addCharacter(character)
    
    def addCharacter(self, character):
        if character not in self.char2index.keys():
            self.char2index[character] = self.n_chars
            self.index2char[self.n_chars] = character
            self.n_chars += 1
            
            
def indexesFromText(lang, text):
    """returns indexes for all character given the text in the specified language"""
    return [lang.char2index[char] for char in text]

def tensorFromText(lang, text):
    """construct a tensor given the text in the specified language"""
    indexes = indexesFromText(lang, text)
    indexes.append(lang.char2index[END_token])
    
    no_padded_seq_length = len(indexes) # Number of characters in the text (including <END> token)
    # Add padding token to make all tensors in the same length
    for i in range(len(indexes), MAX_LENGTH): # padding
        indexes.append(lang.char2index[PAD_token])
        
    return torch.tensor(indexes, dtype=torch.long), no_padded_seq_length

def filterPair(p1, p2):
    """filter for the pair the both texts has length less than `MAX_LENGTH`"""
    return len(p1) < MAX_LENGTH and len(p2) < MAX_LENGTH

def tensorsFromPair(pair, lang1, lang2):
    """construct two tensors from a pair of source and target text specified by source and target language"""
    input_tensor, input_length = tensorFromText(lang1, pair[0])
    target_tensor, target_length = tensorFromText(lang2, pair[1])
    return input_tensor, target_tensor, input_length, target_length



class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        input_text, target_text, lang_th, lang_th_romanized = sample['input_text'], sample['target_text'],                                                               sample['lang_th'], sample['lang_th_romanized']

        input_tensor, target_tensor, input_length, target_length = tensorsFromPair([input_text, target_text], 
                                                                                   lang_th, 
                                                                                   lang_th_romanized)
        
        return {
                'input_text': input_text,
                'target_text': target_text,
                'input_length': input_length,
                'target_length': target_length,
                'input_tensor': input_tensor,
                'target_tensor': target_tensor
               }
    
    
class ThaiRomanizationDataset(Dataset):
    """Thai Romanization Dataset class"""
    def __init__(self, 
                 data_path, 
                 transform=transforms.Compose([ ToTensor() ])):

        input_texts, target_texts = load_data(data_path)
        
        self.input_texts = input_texts
        self.target_texts = target_texts
        self.transform = transform
        self.lang_th = None
        self.lang_th_romanized = None
        self.counter = Counter()
        self.pairs = []
        self.prepareData()

    def prepareData(self):
        self.lang_th = Language('th', is_input=True)
        self.lang_th_romanized = Language('th_romanized', is_input=False)
        for i in range(len(self.input_texts)):
            
            input_text = str(self.input_texts[i])
            target_text = str(self.target_texts[i])
            
            # Count the number of input and target sequences with length `x`
            self.counter.update({ 
                                  'len_input_{}'.format(len(input_text)): 1, 
                                  'len_target_{}'.format(len(target_text)): 1 
                                })
            
            if filterPair(input_text, target_text):
                self.pairs.append((input_text, target_text))
                self.lang_th.addText(input_text)
                self.lang_th_romanized.addText(target_text)    

    def __len__(self):
        return len(self.pairs)
    
    def __getitem__(self, idx):
        
        sample = dict()
        sample['input_text'] = self.pairs[idx][0]
        sample['target_text'] = self.pairs[idx][1]
        
        sample['lang_th'] = self.lang_th
        sample['lang_th_romanized'] = self.lang_th_romanized

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
class Encoder(nn.Module):
    
    def __init__(self, vocabulary_size, embedding_size, hidden_size, dropout=0.5):
        """Constructor"""
        super(Encoder, self).__init__()
        
        self.hidden_size = hidden_size
        self.character_embedding = nn.Embedding(vocabulary_size, embedding_size)
        self.lstm = nn.LSTM(input_size=embedding_size, 
                            hidden_size=hidden_size // 2, 
                            bidirectional=True,
                            batch_first=True)
        
        self.dropout = nn.Dropout(dropout)


    def forward(self, sequences, sequences_lengths):
        batch_size = sequences.size(0)
        self.hidden = self.init_hidden(batch_size) # batch_size

        # sequences :(batch_size, sequence_length=MAX_LENGTH)
        # sequences_lengths: (batch_size)  # an 1-D indicating length of each sequence (excluded <PAD> token) in `seq`
        
        # 1. Firstly we sort `sequences_lengths` according to theirs values and keep list of indexes to perform sorting
        sequences_lengths = np.sort(sequences_lengths)[::-1] # sort in ascending order and reverse it
        index_sorted = np.argsort(-sequences_lengths) # use negation in sort in descending order
        index_unsort = np.argsort(index_sorted) # to unsorted sequence
        
        
        # 2. Then, we change position of sequence in `sequences` according to `index_sorted`
        index_sorted = torch.from_numpy(index_sorted)
        sequences = sequences.index_select(0, index_sorted)
        
        # 3. Feed to Embedding Layer
        
        sequences = self.character_embedding(sequences)
        sequences = self.dropout(sequences)
        
#         print('sequences',sequences.size(), sequences)
            
        # 3. Use function: pack_padded_sequence to let LSTM packed input with same length at time step T together
        
        # Quick fix: Use seq_len.copy(), instead of seq_len to fix `Torch.from_numpy not support negative strides`
        # ndarray.copy() will alocate new memory for numpy array which make it normal, I mean the stride is not negative any more.

        sequences_packed = nn.utils.rnn.pack_padded_sequence(sequences,
                                                             sequences_lengths.copy(),
                                                             batch_first=True)
#         print('sequences_packed', sequences_packed)

        # 4. Feed to LSTM
        sequences_output, self.hidden = self.lstm(sequences_packed, self.hidden)
        
        # 5. Unpack
        sequences_output, _ = nn.utils.rnn.pad_packed_sequence(sequences_output, batch_first=True)

        # 6. Un-sort by length
        index_unsort = torch.from_numpy(index_unsort)
        sequences_output = sequences_output.index_select(0, Variable(index_unsort))

#         print('hidden shape', self.hidden[0].shape, self.hidden[0], self.hidden[1].shape, self.hidden[1])
        return sequences_output, self.hidden
    
    def init_hidden(self, batch_size):
        h_0 = torch.zeros([2, batch_size, self.hidden_size // 2], requires_grad=True)
        c_0 = torch.zeros([2, batch_size, self.hidden_size // 2], requires_grad=True)
        
        return (h_0, c_0)

# %%
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()

        self.method = method
        self.hidden_size = hidden_size

        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)

        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.other = nn.Parameter(torch.FloatTensor(1, hidden_size))

    def forward(self, hidden, encoder_outputs, mask):
        # hidden: B x 1 x h ; 
        # encoder_outputs: B x S x h

        # Calculate energies for each encoder output
        if self.method == 'dot':
            attn_energies = torch.bmm(encoder_outputs, hidden.transpose(1, 2)).squeeze(2)  # B x S
        elif self.method == 'general':
            attn_energies = self.attn(encoder_outputs.view(-1, encoder_outputs.size(-1)))  # (B * S) x h
            attn_energies = torch.bmm(attn_energies.view(*encoder_outputs.size()),
                                      hidden.transpose(1, 2)).squeeze(2)  # B x S
        elif self.method == 'concat':
            attn_energies = self.attn(
                torch.cat((hidden.expand(*encoder_outputs.size()), encoder_outputs), 2))  # B x S x h
            attn_energies = torch.bmm(attn_energies,
                                      self.other.unsqueeze(0).expand(*hidden.size()).transpose(1, 2)).squeeze(2)

        attn_energies = attn_energies.masked_fill(mask == 0, -1e10)

        # Normalize energies to weights in range 0 to 1
        return F.softmax(attn_energies, 1)

class AttentionDecoder(nn.Module): 
    
    def __init__(self, vocabulary_size, embedding_size, hidden_size, dropout=0.5):
        """Constructor"""
        super(AttentionDecoder, self).__init__()
        self.vocabulary_size = vocabulary_size
        self.hidden_size = hidden_size
        self.character_embedding = nn.Embedding(vocabulary_size, embedding_size)
        self.lstm = nn.LSTM(input_size=embedding_size + self.hidden_size,
                            hidden_size=hidden_size,
                            bidirectional=False,
                            batch_first=True)
        
        self.attn = Attn(method="general", hidden_size=self.hidden_size)
        self.linear = nn.Linear(hidden_size * 2, vocabulary_size)
        
        self.dropout = nn.Dropout(dropout)

        
    def forward(self, input, last_hidden, last_context, encoder_outputs, mask):
        """"Defines the forward computation of the decoder"""
        # input: (B, 1) ,
        # last_hidden: (num_layers * num_directions, B, hidden_dim)
        # last_context: (B, 1, hidden_dim)
        # encoder_outputs: (B, S, hidden_dim)
        
        embedded = self.character_embedding(input)
        embedded = self.dropout(embedded)
        
        # embedded: (batch_size, emb_dim)
        rnn_input = torch.cat((embedded, last_context), 2)

        output, hidden = self.lstm(rnn_input, last_hidden)        
        attn_weights = self.attn(output, encoder_outputs, mask)  # B x S
    
        #  context = (B, 1, S) x (B, S, hidden_dim)
        #  context = (B, 1, hidden_dim)
        context = attn_weights.unsqueeze(1).bmm(encoder_outputs)  
        
        output = torch.cat((context.squeeze(1), output.squeeze(1)), 1)
        output = self.linear(output)
        
        return output, hidden, context, attn_weights

# %%
class Seq2Seq(nn.Module): 

    def __init__(self, encoder, decoder):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.pad_idx = 0

        assert encoder.hidden_size == decoder.hidden_size
    
    def create_mask(self, source_seq):
        mask = (source_seq != self.pad_idx)
        return mask
        
  
    def forward(self, source_seq, source_seq_len, target_seq, teacher_forcing_ratio = 0.5):
        """
            Parameters:
                - source_seq: (batch_size x MAX_LENGTH) 
                - source_seq_len: (batch_size x 1)
                - target_seq: (batch_size x MAX_LENGTH)

            Returns
        """
        batch_size = source_seq.size(0)
        start_token = char_to_ix["<start>"]
        end_token = char_to_ix["<end>"]
        max_len = MAX_LENGTH
        target_vocab_size = self.decoder.vocabulary_size

        # init a tensor to store decoder outputs
        outputs = torch.zeros(max_len, batch_size, target_vocab_size)
        
        if target_seq is None:
            assert teacher_forcing_ratio == 0, "Must be zero during inference"
            inference = True
        else:
            inference = False

    
        # feed mini-batch source sequences into the `Encoder`
        encoder_outputs, encoder_hidden = self.encoder(source_seq, source_seq_len)

        # create a Tensor of first input for the decoder
        decoder_input = torch.tensor([[start_token] * batch_size]).view(batch_size, 1)
        
        # Initiate decoder output as the last state encoder's hidden state
        decoder_hidden_0 = torch.cat([encoder_hidden[0][0], encoder_hidden[0][1]], dim=1).unsqueeze(dim=0)
        decoder_hidden_1 = torch.cat([encoder_hidden[1][0], encoder_hidden[1][1]], dim=1).unsqueeze(dim=0)
        decoder_hidden = (decoder_hidden_0, decoder_hidden_1) # (hidden state, cell state)

        # define a context vector
        decoder_context = Variable(torch.zeros(encoder_outputs.size(0), encoder_outputs.size(2))).unsqueeze(1)
        
        max_source_len = encoder_outputs.size(1)
        mask = self.create_mask(source_seq[:, 0:max_source_len])
            
       
        for di in range(max_len):
            decoder_output, decoder_hidden, decoder_context, attn_weights = self.decoder(decoder_input,
                                                                                    decoder_hidden,
                                                                                    decoder_context,
                                                                                    encoder_outputs,
                                                                                    mask)
            # decoder_output: (batch_size, target_vocab_size)

            topv, topi = decoder_output.topk(1)
            outputs[di] = decoder_output
    
            teacher_force = random.random() < teacher_forcing_ratio


            decoder_input = target_seq[:, di].reshape(batch_size, 1) if teacher_force else topi.detach() 

            if inference and decoder_input == end_token:
                return outputs[:di]
        return outputs

# %%
def inference(model, text, char_2_ix, ix_2_char, target_char_to_ix, ix_to_target_char):
    input_seq =  [ch for ch in text] +  ['<end>']
    numericalized = [char_2_ix[ch] for ch in input_seq] 
    
#     print('input ',numericalized)
    sentence_length = [len(numericalized)]

    tensor = torch.LongTensor(numericalized).view(1, -1) 
    
#     print(tensor)
    translation_tensor_logits = model(tensor, sentence_length, None, 0) 
#     print(translation_tensor_logits)
    if translation_tensor_logits.size(0) == 0:
        translation_indices = [0]
        translation = ['<pad>']
    else:
        translation_tensor = torch.argmax(translation_tensor_logits.squeeze(1), 1).cpu().numpy()
        translation_indices = [t for t in translation_tensor]
        translation = [ix_to_target_char[t] for t in translation_tensor]
    return ''.join(translation), translation_indices

# %%
def load_model(model_path):
    
    data = torch.load(model_path)
    
    INPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM, ENC_DROPOUT = data['encoder_params']
    OUTPUT_DIM, DEC_EMB_DIM, DEC_HID_DIM, DEC_DROPOUT = data['decoder_params']

    
    encoder = Encoder(INPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM)
    decoder = AttentionDecoder(OUTPUT_DIM, DEC_EMB_DIM, DEC_HID_DIM)

    model = Seq2Seq(encoder, decoder)
    
    model.load_state_dict(data['model_state_dict'])
    
    
    learning_rate = 0.001
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    optimizer.load_state_dict(data['optimizer_state_dict'])
    criterion = nn.CrossEntropyLoss(ignore_index = 0)

    char_to_ix = data['char_to_ix']
    ix_to_char = data['ix_to_char'] 
    target_char_to_ix = data['target_char_to_ix']
    ix_to_target_char = data['ix_to_target_char']
    
    
    return {
        'model': model,
        'optmizer': optimizer,
        'char_to_ix': char_to_ix,
        'ix_to_char' : ix_to_char,
        'target_char_to_ix': target_char_to_ix,
        'ix_to_target_char': ix_to_target_char
    }

# %%
data=load_model("model/thai2rom-pytorch-25.attn.v6.best_epoch-25.tar")

# %%
model = data['model']

# %%
data
# Out:
# {'model': Seq2Seq(
#    (encoder): Encoder(
#      (character_embedding): Embedding(40, 128)
#      (lstm): LSTM(128, 128, batch_first=True, bidirectional=True)
#      (dropout): Dropout(p=0.5, inplace=False)
#    )
#    (decoder): AttentionDecoder(
#      (character_embedding): Embedding(93, 128)
#      (lstm): LSTM(384, 256, batch_first=True)
#      (attn): Attn(
#        (attn): Linear(in_features=256, out_features=256, bias=True)
#      )
#      (linear): Linear(in_features=512, out_features=93, bias=True)
#      (dropout): Dropout(p=0.5, inplace=False)
#    )
#  ),
#  'optmizer': Adam (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      eps: 1e-08
#      lr: 0.001
#      maximize: False
#      weight_decay: 0
#  ),
#  'char_to_ix': {'<PAD>': 0,
#   '<UNK>': 1,
#   '<start>': 2,
#   '<end>': 3,
#   'k': 4,
#   'a': 5,
#   's': 6,
#   'e': 7,
#   'm': 8,
#   ' ': 9,
#   'b': 10,
#   'u': 11,
#   'n': 12,
#   'h': 13,
#   'i': 14,
#   'r': 15,
#   'o': 16,
#   't': 17,
#   'p': 18,
#   'g': 19,
#   'w': 20,
#   'l': 21,
#   'd': 22,
#   'c': 23,
#   'y': 24,
#   'f': 25,
#   '1': 26,
#   '(': 27,
#   ')': 28,
#   '2': 29,
#   '5': 30,
#   '3': 31,
#   '6': 32,
#   '4': 33,
#   '7': 34,
#   '0': 35,
#   '!': 36,
#   '9': 37,
#   '8': 38,
#   '"': 39},
#  'ix_to_char': {0: '<PAD>',
#   1: '<UNK>',
#   2: '<start>',
#   3: '<end>',
#   4: 'k',
#   5: 'a',
#   6: 's',
#   7: 'e',
#   8: 'm',
#   9: ' ',
#   10: 'b',
#   11: 'u',
#   12: 'n',
#   13: 'h',
#   14: 'i',
#   15: 'r',
#   16: 'o',
#   17: 't',
#   18: 'p',
#   19: 'g',
#   20: 'w',
#   21: 'l',
#   22: 'd',
#   23: 'c',
#   24: 'y',
#   25: 'f',
#   26: '1',
#   27: '(',
#   28: ')',
#   29: '2',
#   30: '5',
#   31: '3',
#   32: '6',
#   33: '4',
#   34: '7',
#   35: '0',
#   36: '!',
#   37: '9',
#   38: '8',
#   39: '"'},
#  'target_char_to_ix': {'<PAD>': 0,
#   '<start>': 1,
#   '<end>': 2,
#   'เ': 3,
#   'ก': 4,
#   'ษ': 5,
#   'ม': 6,
#   ' ': 7,
#   'บ': 8,
#   'ุ': 9,
#   'ญ': 10,
#   'า': 11,
#   'ห': 12,
#   'ั': 13,
#   'น': 14,
#   'ิ': 15,
#   'โ': 16,
#   'ร': 17,
#   'ธ': 18,
#   'ศ': 19,
#   'ล': 20,
#   'พ': 21,
#   '่': 22,
#   'ท': 23,
#   'ย': 24,
#   '์': 25,
#   'ี': 26,
#   'ต': 27,
#   'อ': 28,
#   '็': 29,
#   'ง': 30,
#   'แ': 31,
#   'ซ': 32,
#   'ส': 33,
#   'ว': 34,
#   'ะ': 35,
#   'ำ': 36,
#   'ด': 37,
#   'จ': 38,
#   'ค': 39,
#   'ณ': 40,
#   'ฑ': 41,
#   'ึ': 42,
#   '้': 43,
#   'ู': 44,
#   'ฤ': 45,
#   'ฐ': 46,
#   'ข': 47,
#   'ฒ': 48,
#   'ฎ': 49,
#   'ป': 50,
#   'ไ': 51,
#   'ช': 52,
#   'ฏ': 53,
#   'ภ': 54,
#   'ฆ': 55,
#   'ฟ': 56,
#   'ฮ': 57,
#   'ื': 58,
#   'ผ': 59,
#   '๋': 60,
#   'ใ': 61,
#   '๊': 62,
#   'ถ': 63,
#   'ฌ': 64,
#   'ฉ': 65,
#   'ฝ': 66,
#   'ฬ': 67,
#   '.': 68,
#   'ฦ': 69,
#   '(': 70,
#   ')': 71,
#   'ฯ': 72,
#   '-': 73,
#   'ฃ': 74,
#   'ๆ': 75,
#   '2': 76,
#   'ๅ': 77,
#   'ฅ': 78,
#   'ฺ': 79,
#   'ํ': 80,
#   '5': 81,
#   '3': 82,
#   '6': 83,
#   '4': 84,
#   '7': 85,
#   '1': 86,
#   '0': 87,
#   '!': 88,
#   '9': 89,
#   '8': 90,
#   '"': 91,
#   '๙': 92},
#  'ix_to_target_char': {0: '<PAD>',
#   1: '<start>',
#   2: '<end>',
#   3: 'เ',
#   4: 'ก',
#   5: 'ษ',
#   6: 'ม',
#   7: ' ',
#   8: 'บ',
#   9: 'ุ',
#   10: 'ญ',
#   11: 'า',
#   12: 'ห',
#   13: 'ั',
#   14: 'น',
#   15: 'ิ',
#   16: 'โ',
#   17: 'ร',
#   18: 'ธ',
#   19: 'ศ',
#   20: 'ล',
#   21: 'พ',
#   22: '่',
#   23: 'ท',
#   24: 'ย',
#   25: '์',
#   26: 'ี',
#   27: 'ต',
#   28: 'อ',
#   29: '็',
#   30: 'ง',
#   31: 'แ',
#   32: 'ซ',
#   33: 'ส',
#   34: 'ว',
#   35: 'ะ',
#   36: 'ำ',
#   37: 'ด',
#   38: 'จ',
#   39: 'ค',
#   40: 'ณ',
#   41: 'ฑ',
#   42: 'ึ',
#   43: '้',
#   44: 'ู',
#   45: 'ฤ',
#   46: 'ฐ',
#   47: 'ข',
#   48: 'ฒ',
#   49: 'ฎ',
#   50: 'ป',
#   51: 'ไ',
#   52: 'ช',
#   53: 'ฏ',
#   54: 'ภ',
#   55: 'ฆ',
#   56: 'ฟ',
#   57: 'ฮ',
#   58: 'ื',
#   59: 'ผ',
#   60: '๋',
#   61: 'ใ',
#   62: '๊',
#   63: 'ถ',
#   64: 'ฌ',
#   65: 'ฉ',
#   66: 'ฝ',
#   67: 'ฬ',
#   68: '.',
#   69: 'ฦ',
#   70: '(',
#   71: ')',
#   72: 'ฯ',
#   73: '-',
#   74: 'ฃ',
#   75: 'ๆ',
#   76: '2',
#   77: 'ๅ',
#   78: 'ฅ',
#   79: 'ฺ',
#   80: 'ํ',
#   81: '5',
#   82: '3',
#   83: '6',
#   84: '4',
#   85: '7',
#   86: '1',
#   87: '0',
#   88: '!',
#   89: '9',
#   90: '8',
#   91: '"',
#   92: '๙'}}

# %%
char_to_ix = data['char_to_ix']
ix_to_char =  data['ix_to_char']
target_char_to_ix = data['target_char_to_ix']
ix_to_target_char = data['ix_to_target_char']

# %%
char_2_ix=char_to_ix
ix_2_char=ix_to_char

# %%
model
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (character_embedding): Embedding(40, 128)
#     (lstm): LSTM(128, 128, batch_first=True, bidirectional=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): AttentionDecoder(
#     (character_embedding): Embedding(93, 128)
#     (lstm): LSTM(384, 256, batch_first=True)
#     (attn): Attn(
#       (attn): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (linear): Linear(in_features=512, out_features=93, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
input_text="maeo"

# %%
prediction, indices = inference(model, input_text, char_2_ix, ix_2_char, target_char_to_ix, ix_to_target_char)

# %%
prediction.replace('<end>','')
# Out:
# 'มมมว'

# %%
def inference2(model, text, char_2_ix, ix_2_char, target_char_to_ix, ix_to_target_char):
    input_seq =  [ch for ch in text] +  ['<end>']
    numericalized = [char_2_ix[ch] for ch in input_seq] 
    
#     print('input ',numericalized)
    sentence_length = [len(numericalized)]

    tensor = torch.LongTensor(numericalized).view(1, -1) 
    return tensor, sentence_length, None, 0

# %%
def run2(word):
    return inference2(model, word, char_2_ix, ix_2_char, target_char_to_ix, ix_to_target_char)

# %%
def run(word):
    prediction, indices = inference(model, word, char_2_ix, ix_2_char, target_char_to_ix, ix_to_target_char)
    return prediction.replace('<end>','')

# %%
run2("tontan")
# Out:
# (tensor([[17, 16, 12, 17,  5, 12,  3]]), [7], None, 0)

# %%
run("tontan")
# Out:
# 'ต้นตัน'

# %%
#test_input_texts, test_target_texts

# %%
pred=[]
model.eval()
for i in tqdm(test_input_texts):
    pred.append(run(i))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=99811.0), HTML(value='')))

# %%
test_target_texts
# Out:
# ['กัลยา จันทร์มูล',
#  'กานต์ เลิศสุขทวี',
#  'ไกรสร มูลผึ้ง',
#  'กนกทิพย์ เลาหะวัฒน์',
#  'กระปุกหลุก',
#  'เกณิกา คุโระดะ',
#  'กมล เรืองจันทร์',
#  'กันธิชา จักตรี',
#  'กาจ เชื้อศรีลา',
#  'กรวิการ์ สหัสจันทร์',
#  'กุหลาบ บัวอินทร์',
#  'กรรณิการ์ เครือฟั่น',
#  'กอบกุล อิงคุทานนท์',
#  'กุสุมา พ้นทุกข์',
#  'กฤษณ์ กิติโกเศศ',
#  'กิตติ ตรงเนตรปัญญา',
#  'กลิ่นทิพย์ พิมพ์เงิน',
#  'แกนกล้วย',
#  'กฤติน ติลกานนท์',
#  'กระจ่าง จรปรุ',
#  'กุนจง จุทานิตย์',
#  'กำแพงภาษี',
#  'กฤติยา สุทธกุล',
#  'ไกรสิงห์ ชินพระวอ',
#  'เกษร กาปัญญา',
#  'กรณ์ รังรักษ์',
#  'เกียรติพนม สมพิลา',
#  'กุหลาบ เจริญพูล',
#  'กัลยา เทพแดง',
#  'เกียดกัน',
#  'กนกภรณ์ ร่างสม',
#  'กุลิสรา อรุณแสง',
#  'เกษรี ดีประดับ',
#  'กฤษฎิ์ สุจิตธารากุล',
#  'กิตติคุณ ตั้งศรีวงษ์',
#  'กันตภณ อ่วมสะอาด',
#  'โกวิท มาลัยศิริรัตน์',
#  'กมลวรรณ มีพันธ์',
#  'กวีพจน์ การะเกตุ',
#  'กฤษณะ จันทร์แก้ว',
#  'แก้ววันดี ผาภูมิ',
#  'กรีเทพ กลิ่นชั้น',
#  'กนก บุณยะรัตเวช',
#  'แก้วตา เพ็ญศรีชล',
#  'กุหลาบ มดนาก',
#  'ใกล้รุ่ง บุญโชค',
#  'กัลยา เกิดประวัติ',
#  'กิตติโชติ ทัพวงศ์',
#  'การแผดเสียง',
#  'กะเบือ',
#  'เกรียงศักดิ์ ชูมณี',
#  'เกศรี ตระหง่านศรี',
#  'กมลวรรณ เกิดนาแซง',
#  'ไกล้รุ่ง แดงหิรัญ',
#  'เก็บ อำไพ',
#  'กนกวรรณ เรือนงาม',
#  'เกษม กุฎีรัตน์',
#  'การคลายเครียด',
#  'กัลยกร วีระเสรี',
#  'กรรณิกา น้อยเพิ่มพูล',
#  'เกศกนก คำจา',
#  'เกศทิพย์ ศุภวานิช',
#  'เกษร ฉับพลัน',
#  'กมลฉันท์ มีแสง',
#  'กรุณา พึ่งรัตนะ',
#  'กรองแก้ว อุตสาห์',
#  'กนกอร พลบุญ',
#  'กมล สังข์สุข',
#  'กิติพงศ์ เต๋จ๊ะ',
#  'กรรณิการ์ ไวว่อง',
#  'แก้ว จันทร์มา',
#  'กิตติภูมิ เกตุภู่',
#  'กมลทิพย์ เทียนโสภา',
#  'กมล คงด้วยแก้ว',
#  'กำพล เนียวกุล',
#  'กิติศักดิ์ ดิษกร',
#  'กิมพิ้ง แซ่อึ้ง',
#  'กนกวรรณ์ ทำศรี',
#  'กานดา คำคงสัตย์',
#  'กาเดช กาเด็น',
#  'กิ่งกาญจน์ สว่างศรี',
#  'กฤษณา ปรีชาชาติ',
#  'กุสุมา บุญลอย',
#  'แกลส',
#  'กิ่งแก้ว แซ่อื้อ',
#  'กาเซ็ม พวงมณี',
#  'กัณฑ์อเนก แซ่ตั้ง',
#  'ก่อเกียรติ เกตุกลิ่น',
#  'กุ้ยฮ้อ แซ่จึง',
#  'เกียรติศักดิ์ ศิริ',
#  'กาญจนา เซี่ยงจง',
#  'เกศินี สุวศราภรณ์',
#  'กุลปราณี อัสมิมานะ',
#  'กุลพงษ์ อ้นมณี',
#  'กุลมณี ฑีร์ฆะยศ',
#  'กอบัว เหล่ารุจิจินดา',
#  'แก้วดี พรหมฟัง',
#  'กันยารัตน์ ทองเครือ',
#  'กนกรัตน์ ประสพ',
#  'กำหนัด',
#  'กวี จันทร์สา',
#  'กรุง กรุตอาชา',
#  'แกรห์ม',
#  'กอบศักดิ์ จินตกานนท์',
#  'กฤษณะ โอภาศ',
#  'กริตติศักดิ์ สาสนกูล',
#  'กฤษณพล เสนามาตย์',
#  'ก่อบุญ มาจุฬา',
#  'กำพล ยศนนท์',
#  'กนกพร มกรนันท์',
#  'โกวิทย์ วิชัยจิตร',
#  'กิตติเชษฐ์ หัตธรรมโม',
#  'กนกพรรณ โลหะ',
#  'กิตติพงษ์ เสาร์ดี',
#  'กุศล แซ่อึ้ง',
#  'กัลยา เตียงเกตุ',
#  'ฤกษ์ชัย สุขสำราญ',
#  'การทำสมาธิ',
#  'ไกรสร ผสมทรัพย์',
#  'กานต์สินี ซเว่นเซ่น',
#  'กันหา เอี้ยวสกุล',
#  'กิตติพงษ์ ถาพันธุ์',
#  'กนกอร ศรีสุขใส',
#  'กรวิกา วงษ์ผาบ',
#  'กระเช้าผีมด',
#  'กุลนิษฐ์ นันทะแสน',
#  'กฤษณ์ บุญนิธี',
#  'การแข่งขัน',
#  'เกศสุดา กูลเมือง',
#  'กำพล แสงสุข',
#  'กำจัด ก้านขุนทด',
#  'โกลฟ',
#  'กิตติภณ บุญพามี',
#  'กนกวรรณ อ่วมสน',
#  'กรวิทย์ โตใหญ่',
#  'เกษม ศิริเจริญ',
#  'ก่องกาญจน์ สิงห์สมดี',
#  'กิตติโชติ บุรีรัตน์',
#  'กนกนุช หลักฐานดี',
#  'กิจจา พิมพ์ทอง',
#  'กฤษณะ ณรงค์ศรี',
#  'กรรณิกา ศรีประเวช',
#  'กวินธิดา ศิริเขตต์',
#  'กมลทิพย์ ชูศรี',
#  'กิตติคุณ คงอยู่',
#  'กฤตยา วันชื่น',
#  'กรุณา เพชรสุกใส',
#  'เกาะกลุ่ม',
#  'กุหลาบ จันทร์แก้ว',
#  'กนกอร พูลพิพัฒน์',
#  'กิมไล้ ปฎิทัศน์',
#  'กร รอดทอง',
#  'กองแก้ว หวังบุญ',
#  'กัญญา มคธเพศ',
#  'กัลยดา สินเกษม',
#  'กฤตภัค ศรีสะอาด',
#  'กรรฐา',
#  'กิตฎา เต็นรัมย์',
#  'กิตติคุณ อุมาสะ',
#  'เกศรา สง่ากอง',
#  'กินนรี ชนะสิทธิ์',
#  'เกษม นินาทปัญญา',
#  'เกรียงศักดิ์ คงคะดี',
#  'กิตติ คำพร้อม',
#  'แก่นแก้ว ปัญญา',
#  'กรมยุโรป',
#  'กาย คงโต',
#  'กาญจนา รสานนท์',
#  'กรกมล สุขแก้ว',
#  'เกษา สุขสมโสด',
#  'เกษม แปนขาม',
#  'กาหลง พลเจียง',
#  'กฤตยา ศรีสันติสุข',
#  'กิมหงวน แซ่อึ้ง',
#  'กิติมา สายนุ้ย',
#  'กฤษณ์ จิตนุยานนท์',
#  'กุลจิรา ชัยวิจิตร',
#  'เกษม ลาดสะอาด',
#  'เกษม โลจายะ',
#  'เกสร อธิโภชน์',
#  'ไกรเดช พันธจักร',
#  'กิตติธัช บุญชะโด',
#  'กองสี หงอกไผ่',
#  'กิติพล คงสมัย',
#  'การบูรณะชนบท',
#  'กายวรรณ หมื่นบุญมี',
#  'กัญญา อนันตชาติ',
#  'กิตติรัช ชาติไทย',
#  'กุลวดี รักการดี',
#  'กริชชัย ผลาวะสุ',
#  'กัญทร ทัศนศร',
#  'กิตติ บุญประกอบ',
#  'กุหลาบ เยนเซ่น',
#  'กันตภณ โชติชัยศรี',
#  'กมล พันพรสิน',
#  'กนกวรรณ มุสตอฟาดี',
#  'เกรียงศักดิ์ ชูเมฆ',
#  'กมลกาจ รุ่งปิ่น',
#  'กาญจนา แซ่จัง',
#  'กฤติยา เสตะพันธุ',
#  'การุณ วาฮา',
#  'กัตติกา สาลักษณ์',
#  'กนิษฐา กิจสมบัติ',
#  'กษมล ภูมิวสนะ',
#  'กฏ เกตุกสิณ',
#  'เกษม วีระชุนย์',
#  'กนกวรรณ จอมพงษ์',
#  'กิตติ เลาหธนสาร',
#  'กิตติศักดิ์ ชัยโรจน์',
#  'กฤษณะ บุญใช้',
#  'กฤติฎา ปริยพรรณ',
#  'โกวิทย์ พาดพิทักษ์',
#  'กิติภูมิ จิตต์กุศล',
#  'กีรติญา มะลาไสย',
#  'กุลนิตย์ เขียวสวาท',
#  'กุลชลี ดาระกะมาศ',
#  'เกษมสัน คงจันทร์',
#  'กสิณา จันทร์งาม',
#  'กิมไล้ มงคลสืบ',
#  'กมลวรรณ พันธุ์เจริญ',
#  'กาญจนา ไชยลังกา',
#  'กุลยา พิสิษฐเกษม',
#  'กลิ่นสุคนธ์ แสงแก้ว',
#  'ก่วงตง',
#  'กิมล้วน เหลืองงามตา',
#  'กชกร เนตรสุวรรณ์',
#  'กาญจนา ฮวบสกุล',
#  'กัลยา ผัดผ่อง',
#  'การรับรอง',
#  'กุลฉวี กำจายภัย',
#  'กีรติ บุญศิลป์',
#  'โกไสย สุวรรณวัฒน์',
#  'กาญจนา กันทะคำ',
#  'โกมินทร์ ชุ่มชื่น',
#  'กฤติยา ปัญญานนท์วาท',
#  'กานดา แกล้วกล้า',
#  'กมลทิพย์ สยมชัย',
#  'กัลยาจิตร มีแสง',
#  'กนกวรรณ สุมาลัย',
#  'กนกวรรณ วิศิษฏานนท์',
#  'กันยา ดวงปินตา',
#  'กิติยา วารีดี',
#  'ไกรเลิศ จันทร์แก้ว',
#  'กัลยา พรมเสน',
#  'เกรียงศักดิ์ ก๊กมาศ',
#  'ไกรสร ศรีเรืองโห้',
#  'กิตติ โสณมัย',
#  'กลอเรีย',
#  'กานท์ พงษ์มาลา',
#  'ไกรสร อ่อนวัน',
#  'กมล ธัญญสุวรรณ์',
#  'กาญจนา วาสิกศิริ',
#  'กัญญา เอกทวีวุฒิ',
#  'แก้ว ฉันทไพจิตร',
#  'กิตติ โพธิ์สุข',
#  'กาญจนา เก่าแสน',
#  'กรปัต นิลพยัคฆ์',
#  'กมลมาลย์ หงษ์ภักดี',
#  'กิ่มกี่ เกิดทองมี',
#  'ไกรสีห์ เวภาระ',
#  'กนกวรรณ รัตนา',
#  'กนัย แซ่ตั่น',
#  'กรปณต แก้วบัวดี',
#  'กัลยา สื่อเฉย',
#  'เกตน์สิรี แตงโสภา',
#  'กำไร สุขปรุง',
#  'กัญญาลักษณ์ จิตรสุข',
#  'กิ่งกมล ใจใส',
#  'กิตติ กอสนาน',
#  'กนกอร อิทธิลัภ',
#  'ไกรสร นาคประดิษฐ',
#  'กนกวรรณ ฟริดแมน',
#  'กิตติ โพนุสิต',
#  'กิตติพงษ์ นาคสู่สุข',
#  'ไกรศรี อภิชัย',
#  'กัญชลา น้าประเสริฐ',
#  'กอบกุล ศรีชุ่ม',
#  'ก้อน จีนมะเริง',
#  'กาจกร ฮวบวัน',
#  'กาญจรัตน์ สุขดี',
#  'กริช แขรัตน์',
#  'กริน ชลิศราพงศ์',
#  'เกษร งามฉวีพันธุ์',
#  'กิตติ กรัพนานนท์',
#  'กาญจนา พงษ์ประยูร',
#  'กัญญา เช็ง',
#  'กำพล ประวรรณา',
#  'กิมเง็ก ตันสุวรรณ',
#  'กรกช แม้นศรีสม',
#  'กันยา พูลทวี',
#  'กรรณิการ์ ธีระพงษ์',
#  'กชพรรณ เภริน',
#  'เกรียงไกร ก่อเกิด',
#  'กรรณิการ์ จั๋นติ๊บ',
#  'ไกรศักดิ์ แจ่มผล',
#  'เก็บกด',
#  'กันตพงศ์ ฟักเขียว',
#  'เกษร มีปัญญา',
#  'กิจจา วงศ์จินดา',
#  'โกเมน ตันฑ์มานะธรรม',
#  'กัลยกร เพ็ชรรัตน์',
#  'กรกรานต์ วิชัยธรรม',
#  'กำลัย ปราบงูเหลือม',
#  'กฤษณะ ร้อยกรุด',
#  'กนกพร บุญญภพ',
#  'กัลยาณี บุญยะเสนา',
#  'กฤษณา โพธิ์ประทับ',
#  'กุยบวย เทพิน',
#  'กฤษณา ภมรสูตร',
#  'กัลยา ชาฎก',
#  'กาวี สุขพรศรี',
#  'กัลยาณี ล้อละมัย',
#  'ก้าน ปลุกใจเสือ',
#  'กาญจนา หุ่นวงศ์ธรรม',
#  'เกษร สาวนายน',
#  'กิมเฮียะ แซ่เอี้ยว',
#  'กาจสรณ โพธิ์จันทร์',
#  'กรรณิการ์ จินตวร',
#  'เกสรา เนตรจั่น',
#  'เกรียงไกร สังข์เงิน',
#  'ก้าน ออทอง',
#  'เกรียงไกร ศรีอเนก',
#  'กฤษฎา เปรมฤทัย',
#  'กายภาพบำบัด',
#  'กันยารัตน์ ผลทอง',
#  'กมล ไชยิ่ง',
#  'กัมปนาท พรหมมาก',
#  'กะมัน',
#  'การุณ เจิดสวัสดิ์',
#  'กมล กาชู',
#  'กนก สุวรรณรังษี',
#  'กิตติ ไพเจริญ',
#  'กรวีร์ หล่อสิงห์คำ',
#  'เกรียงศักดิ์ เกบุตร',
#  'กฤติยา วงษ์ทิ',
#  'กอบศักดิ์ นิ่มอนงค์',
#  'กิตติศักดิ์ ทิวาเวช',
#  'กุศล สะบู่แก้ว',
#  'กฤษฎธรรม ธูปบูชา',
#  'กุลนิตย์ สุนทรโอภาส',
#  'กตัญญู โกมุทมาศ',
#  'กรุณา กอขันธ์',
#  'กุหลาบ เมฆพยม',
#  'เกศิณี เดชสาทัน',
#  'กาญจนา พลราชม',
#  'กณวรรธน์ อรัญ',
#  'กาญจนา สันติศักดิ์',
#  'กิจสกร กล้ากสิกิจ',
#  'กำพล มหาเจริญ',
#  'กัมพล มานะสุข',
#  'กรรณิการ์ มูลทรัพย์',
#  'ไกรสีห์ เอมเปรมศิลป์',
#  'กาหลง สอนสุข',
#  'กฤษณะ เขื่อนเพ็ชร์',
#  'กุลนที แจ้งกรณ์',
#  'เกศวดี แก้วสุวรรณ',
#  'กาหลง ยอดทอง',
#  'กฤษดา ปาลกะวงศ์',
#  'กัลยา ปานฟัก',
#  'กิมลี้ จันพุฒ',
#  'การติดตามต่อเนื่อง',
#  'โกมล สุขเจริญ',
#  'กิตติพัฒน์ โพธิ์พุ่ม',
#  'กี้ กีบสิน',
#  'กนิษฐา แก้วละเอียด',
#  'กิตติ ไชยยันต์บูรณ์',
#  'กรประเสริฐ กุณะด้วง',
#  'กรชนัฐ ร่มโพธิ์ใหญ่',
#  'กิมหงษ์ แซ่ลี้',
#  'กัมพล สุริโย',
#  'กัลย์สุดา ทองมาก',
#  'ก่อดำ',
#  'กาญจนา กุสลา',
#  'กาญจนา ดาบมหาราช',
#  'กุลริศา ส่องแสง',
#  'กนกพร เพิ่มพูน',
#  'กิ่งกาญจน์ อุบลฉาย',
#  'แก้ว สมพร',
#  'กฤษฎา หายโศก',
#  'กฤษณะ ธรรมโกฎิ์',
#  'กาญจนา ท่ากระเบา',
#  'กษมา เจตะสานนท์',
#  'กวีพันธ์ แสงสุข',
#  'กัญชรัศ ไทยยันโต',
#  'เกศณีวรรณ ถูกจิตร์',
#  'กนก กาญจนพันธุ์',
#  'เกษม อินทสังข์',
#  'กานต์นัดดา คุณหอม',
#  'กานดา เยี่ยงแก้ว',
#  'กิมฮง รตะสุขารมย์',
#  'กนกวรรณ กิจนวสิน',
#  'กิตติ สุวรรณวิจารณ์',
#  'กิตติชัย แซ่ตั๋น',
#  'เกษม ศรีสุวรรณ',
#  'ก๊วยตัง แซ่ตั้ง',
#  'กนกวรรณ ศรีเพ็ง',
#  'เกียน ไทยมานิตย์',
#  'กุสุมา นีละนิยม',
#  'กันดาภา ชินวิทย์',
#  'เกรียงศักดิ์ อินทสา',
#  'กอบกุล หวังเจริญ',
#  'กฤตยา คงคามาศ',
#  'กรัณฑ์ ปุณศรี',
#  'กลรัตน์ เพชรสัมฤทธิ์',
#  'กิตติพงศ์ การงาม',
#  'กาญจนา ติระพัฒน์',
#  'เกณฑ์สิทธิ',
#  'กรรณิการ์ ดอนหลักคำ',
#  'เกษร ศิลาอาศน์',
#  'กิตติคุณ ปั้นตะกั่ว',
#  'กรวิ ผิวนวล',
#  'ไกรสร พันนา',
#  'กันยกร ลาสุนนท์',
#  'กฤษณา ดังควัฒนา',
#  'เกดประทุม บุญญะฐี',
#  'การแบ่งปัน',
#  'โกศล สุทธินรเศรษฐ์',
#  'เกื้อ ผกาแก้ว',
#  'กุ้ยเซ้ง แซ่ฉั่ว',
#  'กนกพร ผูกพันธุ์',
#  'กฤษฎา นุรักษ์',
#  'กรรณิการ์ ทิษฐิธรรม',
#  'เกาะกุม',
#  'กรรณิสา สุดขยัน',
#  'กฤษณะ วรรธนะกุล',
#  'กิ่ง สุขสวัสดิ์',
#  'เกษม อินเฮง',
#  'กมล อุ่นแก้ว',
#  'กรรณ์ ขวัญเมือง',
#  'กัลยา เกรียงโกมล',
#  'กฤษณะ คลองละวะ',
#  'กัญจนี ศุนาลัย',
#  'เกษกนก มั่นทิม',
#  'กีรติ ชายยิ้มวงค์',
#  'กิรณา เพ็ชรกลม',
#  'กีส',
#  'โกวิท รัตนราช',
#  'กฤษณา พรมตื้อ',
#  'กฤศณัฏฐ์ ช่วงถึก',
#  'กฤษฎา ผาสุขดี',
#  'กวางม้า',
#  'กรกนก เพ็ชรเขียว',
#  'เกษม ลิ่มวงศ์',
#  'กฤษฎี ปริวัตรกุล',
#  'เกษม จินดาวงค์',
#  'โกศล รังสิมันตุ์วงศ์',
#  'กังวาล เกิดผล',
#  'กุลวดี สมญาดี',
#  'เกษร สุจริต',
#  'กุลชาลี รุ่งสว่าง',
#  'แก้วนภา ทองวรรณ',
#  'กรวดี เปรมชูเกียรติ',
#  'กัลยารัตน์ วีก้า',
#  'เกียง แจ่ง',
#  'การคาดคะเน',
#  'กอบ สักเขตกรรม',
#  'ไกรวุธ จิระบุตร',
#  'กรุยเกรียว',
#  'กฤษฎา นวนจันทร์',
#  'กนกวรรณ สีม่วง',
#  'เกวลี ศรีบุปผา',
#  'โกสินทร์ ด่านพิทักษ์',
#  'กมล เจริญจิตต์',
#  'การขอความเห็น',
#  'เก็จคณี บัวเฟื่อง',
#  'กำเริบกาม',
#  'กชพงศ์ แสงทอง',
#  'กังกะ',
#  'โกวิท ผาสุขมูล',
#  'เกื้อกูล แสนทอง',
#  'กิตติชัย ไกรชิต',
#  'โกศล จั่นทอง',
#  'กิตติศักดิ์ อ้นทอง',
#  'กฤตยะ ตันเปาว์',
#  'กันหา เทพสวัสดิ์',
#  'โกสน จะโนภาศ',
#  'กรกช ชัยชมพู',
#  'กรินทร์ มณีวรรณ',
#  'กฤชอร หวันกะมา',
#  'เกศินี เตชะสุข',
#  'กฤษฎา ดวงกุศล',
#  'กฤษดา เรียงพร',
#  'กฤษฎา วรงาม',
#  'กฤษฎ์ มาณะวิท',
#  'กฤษณา กุลรอด',
#  'กาญจนา ขาวประเสริฐ',
#  'เกษม สินธร',
#  'แก้วฤทธิ์ คัมภ์บุญยอ',
#  'กาญจนา ลือดัง',
#  'กานต์พิชชา อ้อไสว',
#  'กิตติ ไชยสีทา',
#  'กรรณิกา อยู่สงค์',
#  'กาญจนา ปาลา',
#  'กาญจนา นิ่มนวลดี',
#  'เกศณี บุญชม',
#  'กวิสรา นิยกิจ',
#  'กมลฉัตร ทุมาวงศ์',
#  'เกริกฤทธิ์ ไชยมาศ',
#  'กิตติมา อินทะหลาบ',
#  'กมล เครือกนก',
#  'กิม สิทธิกรสกุล',
#  'กัลยาณี งามทิพย์',
#  'ไกรสร ปิงเมือง',
#  'กรวรรณ แก้วเถาว์',
#  'กัญญา พลจันทึก',
#  'กิตติ ขวัญมงคล',
#  'กำธร นามบ้านโนน',
#  'กิ่งกาญจน์ ศรีวิไล',
#  'เกศศิณี แซ่ตั้ง',
#  'กุหลาบ ศรีวิโรจน์',
#  'กฤษฎา ตระกูลโอสถ',
#  'กานติภา แซ่เบ้',
#  'กิจจา แซ่จิ๋ว',
#  'ก้วย',
#  'กัลยา คำบุญทา',
#  'เกษแก้ว สืบสาย',
#  'กฤษดา สอนไวย์',
#  'กล่องเสียง',
#  'กมล การสมเพียร',
#  'เกษตร ภู่ขาว',
#  'กิติธัช ปรุงเกียรติ',
#  'กนิษฐา นันทศิลป์',
#  'กมลพร พลวิฑูรย์',
#  'กิตติมา เอ่งฉ้วน',
#  'กรองทอง เทียนไชย',
#  'กนกวรรณ กัลยา',
#  'กุหลาบ เพชรสังข์',
#  'กุสุมา เนตรสว่าง',
#  'เกรียงไกร ทิพย์โสภา',
#  'ฤกษ์ชัย พีระพงษ์',
#  'กฤษดา ฮาเซะ',
#  'กนกวรรณ นกแก้ว',
#  'กมลวัลย์ เส็งสาย',
#  'เกวลี ถมค้าพาณิชย์',
#  'กมลกร สว่างศรี',
#  'กิตติพงษ์ แซ่เช้า',
#  'เกษร สร้อยสุวรรณ',
#  'กำธร บัณฑุวงศ์',
#  'กมลชนก ทวีทรัพย์',
#  'กาญจนา เจริญพร',
#  'กัลย์นภัส รุจิโกไศย',
#  'กนกวรรณ ลางา',
#  'กิติชัย ทองโคตร',
#  'กาญจนา จุลนัย',
#  'กลิน กลิ่นหอม',
#  'โกศัย ไพทักศรี',
#  'กฤติยา มีสมศักดิ์',
#  'โกศล วรพุฒ',
#  'กัลยา โต๊ะสะและ',
#  'กำพล พาณิชย์วิบูลย์',
#  'กฤษณา ไพรอนันต์',
#  'กมล โต้ติ้น',
#  'กองพล เอี่ยมระหง',
#  'การพัฒนา',
#  'เกษร เคหะทัศน์',
#  'ก้อนแก้ว กาญจโนภาส',
#  'กะดุนง',
#  'กฤติยา สินสมบูรณ์',
#  'กรกนก ชุมชาติ',
#  'แก้ว เกิดมั่งมี',
#  'กิ่งแก้ว ยืนยัง',
#  'กำพล หงษ์โต',
#  'กุลดา สิริวินยานนท์',
#  'กรองจันทร์ สกุลยง',
#  'กิตติพร ไหวไว',
#  'กาญจนา นนท์เดชกูล',
#  'กิตติ ฟ้าปกาสิต',
#  'กิตติพงษ์ ทองขาว',
#  'กันทิมา เกียรติโอภาส',
#  'กมล ภาษยะวัต',
#  'กิตติภพ บุญเสาร์',
#  'กันตินันท์ มูลทองฟัก',
#  'กัลยา ภู่สีเขียว',
#  'กัญญา นึกสมพงษ์',
#  'เกศินี ศรีชำนาญ',
#  'กิมเลี้ยง แซ่ลี้',
#  'กฤษฎา พลเรือง',
#  'เกศศิริ ปานทอง',
#  'กาญจนา พุกเปลี่ยน',
#  'กานต์ ถวัลย์อรรณพ',
#  'เกดแก้ว หงษ์เอี่ยม',
#  'การีม ทองหล่อ',
#  'กษมา วงศ์เจริญ',
#  'การกลาย',
#  'กัญญา ใจรักษา',
#  'แก้วใจ พรหมบุตร',
#  'กิตติ หมื่นสืบ',
#  'กชพร ชลศุข',
#  'กิจจามาศ แสงอรุณ',
#  'กนกพร นกสกุล',
#  'กมลวัน ดิษยบุตร',
#  'กัลยา มนต์พิพัฒน์',
#  'กนกพิญส์ ฤทธิ์รายา',
#  'เกจ์แวคคัม',
#  'กิจจา ณ',
#  'กุลเชฏฐ์ วังน้ำทิพย์',
#  'กชกร ซิมพิทักษ์',
#  'กาย อมตนิรันดร',
#  'การตีความความหมาย',
#  'กัญจนา สิกขชาติ',
#  'กิชพงษ์ ช่างยันต์',
#  'กฤษณา วุฒิสินธ์',
#  'กรกช หัสดิน',
#  'กฤตพร โพธิ์ทอง',
#  'กัญญา ศรแก้ว',
#  'กิมกี ศาสตร์ประเสริฐ',
#  'โกวิทย์ สุดเจริญ',
#  'กิจเกษม หน่อทอง',
#  'การุณ ศรีภัทรานุสรณ์',
#  'กฤษณะ รักษาแดน',
#  'ไกรยุทธ เพ็ญศรี',
#  'เกศริน พันธวงค์',
#  'กรวรรณ แซ่ลิ้ม',
#  'กุลวิภา บุญทร',
#  'กมล อำไพสิริวงศ์',
#  'แก่นจันทร์ ยินมะเริง',
#  'กำเริบ',
#  'กัลยกร ข้อยุ่น',
#  'กิตติยา ศรีจันตะ',
#  'กิตติภัค ขัดคำ',
#  'กษมพงศ์ บุนนาค',
#  'ก้องภพ ใจนักรบ',
#  'กมร กัณฑิโกวิท',
#  'กระจกนิรภัย',
#  'กาญจนา ศรีโกมุท',
#  'กาญจนา ศรีพิทักษ์',
#  'กระตือรือร้น',
#  'กฤตินี สิงหพันธุ์',
#  'กฤษณ กุลศรีรัตน์',
#  'กนกวรรณ อัคลา',
#  'กฤษฎา กังรัตน์',
#  'กิตติพงษ์ เลี่ยมอยู่',
#  'กฤษฎา นุเวที',
#  'เกไล',
#  'กาญจนา ทองรักษ์',
#  'แก้ว จันทร์มูล',
#  'กฤษณ์ อนุตรกุล',
#  'กิตติ เกษมสุวรรณ',
#  'โกมินทร์ บุนนาค',
#  'กุสุมา พรหมผลิน',
#  'เกษมศรี ไทยกล้า',
#  'ไกรวัล อินนาดอน',
#  'กฤษณา ชูทรัพย์',
#  'กู้เกียรติ เฉลิมศรี',
#  'การบริหารที่มิชอบ',
#  'เกศชฎา ศรีติ๊บ',
#  'กัญญาภัค รูปิยาภรณ์',
#  'เกษร วจนรจนา',
#  'โกมล เอี่ยมเสมอ',
#  'กมลรัตน์ ภู่สิงห์',
#  'กฤษดี สรไกร',
#  'กมล ตี๋จรูญ',
#  'โกนากรี',
#  'กาญจน์ทิพ ฉิมอ่อง',
#  'กิณัฏชนา นามโคตร',
#  'กิตตินันท์ ยืนยาว',
#  'กัณฑ์ พรหมสุวรรณ์',
#  'กชพรรณ คมนานุกิจ',
#  'เกรียงศักดิ์ คุณจักร',
#  'โกวิท เอียดศรีชาย',
#  'เก็จกัญญาณี นฤหาย',
#  'กัณการันต์ ชอบจิตร',
#  'กิติยาภรณ์ สอนสุภาพ',
#  'กุลศรา โสณกุล',
#  'กรอนงค์ วงษ์มณี',
#  'ใกล้รุ่ง สุขเกษม',
#  'การเหนี่ยว',
#  'กิตติพงศ์ สุดชาติ',
#  'กิตติ สารสิทธิ์',
#  'กิตติคุณ ก้อนทอง',
#  'โกมล เพชรกุ้ง',
#  'กฤษดา บริสุทธิ์',
#  'เก่งโอว แซ่นิ้ม',
#  'กำพร้า จินตริน',
#  'กุสวดี เพิ่มเจริญ',
#  'กัญญาณี นาคเจริญ',
#  'กิ่งอำเภอแม่ออน',
#  'กฤษณา ผลมะทอง',
#  'กรรณิการ์ ทองเนียม',
#  'เกียรติศักดิ์ ว่องไว',
#  'กิตติ ตาละคำ',
#  'เกษม จันทร์หอม',
#  'กันยา ผลรักษ์',
#  'กนกวรรณ ปวรกุล',
#  'กอบเกียรติ จรัญยากร',
#  'กิตติชัย ลีกรัณย์ชัย',
#  'กาญจนา กลับรอด',
#  'กัญญา เอี่ยมโอธาน',
#  'กษฏาพา คำมี',
#  'กฤษนันท์ ทัพพันธ์',
#  'กุลชไม สหะบุญกูล',
#  'กล้าหาญ โสลี',
#  'กาญจนา เกียรติโอภาส',
#  'กรุงธน ศิริอ่อน',
#  'กาญจนา เกลี้ยงมีศรี',
#  'กาญจนา วิบูลย์ดล',
#  'กฤษณะ วิชาพร',
#  'กิมกี่ แซ่เจียม',
#  'กรรณิการ์ เบ้ามูลตรี',
#  'กรรณิการ์ ชายมินทร์',
#  'กิตติพันธุ์ กิตติเวช',
#  'ก้องเกียรติ หัสพิมพ์',
#  'กุศล สมนึก',
#  'กรรณิการ์ หวังโภคา',
#  'กษิดิ์เดช สิบศิริ',
#  'การต้ม',
#  'เกษม นาคลดา',
#  'กฤษดา ใยสุหร่าย',
#  'กตัญญู จิตรชื่น',
#  'กานดา ศรีธรานนท์',
#  'โกศล รากทอง',
#  'กรทอง ปาณิกบุตร',
#  'กันติพงค์ วงศ์หล่อ',
#  'กำปนาท มิลกุล',
#  'กฤษดา ชะบา',
#  'กองชุน มีมะจำ',
#  'แก้ว สุวี',
#  'กฤษณ์กร วงศ์ไทย',
#  'กัญจนา ทองสิงห์',
#  'กาญจนา การ์เซีย',
#  'กฤษณะ แสนคำ',
#  'แกะ อ่วมสวัสดิ์',
#  'กฤษณะ จันทะโก',
#  'แก้วดี ธนันไชย',
#  'กาญจนา ภูยานนท์',
#  'โกมล รอดทับทิม',
#  'กิติญาดา ปรินรัมย์',
#  'กิรณา ก้าวเจริญ',
#  'กิตติ วงษ์จินะ',
#  'เก่งฉกาจ สว่างศิลป์',
#  'กมลทิพย์ รำเพย',
#  'กิตยาภรณ์ แก้วมณี',
#  'กชพรรณ บวรวณิชย์',
#  'กรรหา วงศ์ทิพย์',
#  'กิตติ หยกพวง',
#  'ไกรสีห์ อาชามาส',
#  'กิ่งกาญจน์ เกตุชั่ง',
#  'กรชนก ฉิมจารณ์',
#  'กิติภพ ศรีห่าน',
#  'กิติโพธิ์ ฉัตรไชยเดช',
#  'กชกร มีแตร',
#  'กวิตา แจ้งสว่าง',
#  'กาญจนา หฤษฎ์วงษ์',
#  'กลั่น สุขประเสริฐ',
#  'กรองใจ บินโรสลัน',
#  'กอบกฤต โมระศิลปิน',
#  'กนกภรณ์ วรอุไร',
#  'กังวาล เดชะพันธ์',
#  'กรุณา อิศรางกูร',
#  'กนกวรรณ รักแจ้ง',
#  'กิ่ง แต้มเพ็ชร',
#  'กัมพล จันทวิบูลย์',
#  'กฤษณนันท์ ยังน้อย',
#  'กมล เต่าถมตา',
#  'เกศรินทร์ ฉิมเทศ',
#  'กุลวดี ตัณฑเวส',
#  'กมล สุขขำ',
#  'ก่อพงศ์ อิ่มเอิบ',
#  'แก้วลูน บุญลอย',
#  'กวิน สุปินะเจริญ',
#  'กิ้ง สุคันทา',
#  'กนกวรรณ แซ่เล้า',
#  'กัญญณัช เหลือบชม',
#  'กิตติรัตน์ เงินเรียน',
#  'โกวิท ลัภพระบุตร',
#  'เกศินี เกลี้ยงสง',
#  'กุ้นยิ่น แซ่หลี',
#  'เกษร เงินทองดี',
#  'ใกล้เคียง',
#  'กานตยา กิจสวัสดิ์',
#  'กันตินันท์ สุขกล่ำ',
#  'กิตวดี สงวนศักดิ์',
#  'โกวิท ผลัญชัย',
#  'เก็จฉัตพิ ช่างศรี',
#  'เกษร ธรรมชีวัน',
#  'กำมะหยี่ สินธุสาร',
#  'กมล โกศลสุวิวัฒน์',
#  'กนกวรรณ ฤกษ์ถนอม',
#  'กฤษณะพงศ์ สุภาพ',
#  'กรุณา เพ็ญไพจิตร',
#  'กิตติ ทัพเจริญ',
#  'กิจชัย ทองคู่',
#  'แกรมมา',
#  'กันตยา ฮิลล์',
#  'กิ่งเพชร ฤกษ์เมือง',
#  'กิมยับ เที่ยงคำดี',
#  'กาญจนี กุลสุรกิจ',
#  'กฤษณี ศิวารินทร์',
#  'กนกวรรณ ไทยเจริญ',
#  'กาวิน เรืองอร่าม',
#  'เกษมวิช โลหิตกุล',
#  'กุลธิดา ใบลาภ',
#  'กมลทิพย์ ธรรมวัฒน์',
#  'กาญจนา อุ่นอ้าย',
#  'กาญจนา น้อยวงษ์',
#  'เกษมศรี เสมา',
#  'กิตติพงษ์ วานิช',
#  'กิ่งกาญจน์ เพ็ชรไทย',
#  'การหย่าร้าง',
#  'กฤษดา รสกลิ่น',
#  'เกษม ไกรภู่',
#  'เกษแก้ว อึ้งสายเชื้อ',
#  'กมล สุขสมหมาย',
#  'เกรียงศักดิ์ จันทอง',
#  'ไกรฑูรย์ สุขสนชัย',
#  'กิตติภณ วงษ์อินทร์',
#  'เกรียงศักดิ์ กันไพรี',
#  'กิตตินัย ปิติพัฒน์',
#  'กุลนิวัติ กุลไพบุตร',
#  'กอบพงษ์ นามสง่า',
#  'กมล แซ่เอี๊ยว',
#  'การผสมกลมกลืน',
#  'กาฬสินธุ์ โยธิเสน',
#  'แก้ว แสงสมรส',
#  'แก้ว ยอดคำ',
#  'กันทิมา เพิ่มศรี',
#  'กฤษฎา มณีขันธ์',
#  'เกล้า กุโบลา',
#  'กิตติศักดิ์ พ่วงพูล',
#  'การนำไฟฟ้า',
#  'กาญจนี บุญมาก',
#  'เกษแก้ว ลูกเล็ก',
#  'กร ชูรัตน์',
#  'กาญจนา จุฬามณี',
#  'เกษม ศรีเฟื่องปรางค์',
#  'กรรณิกา นาคเม้า',
#  'ไกรสิทธิ์ มัฆวิบูลย์',
#  'กมลพร ประยูรยิ้ม',
#  'เกษม รัตน์ประสาทพร',
#  'กมลชนก เหล็กอิ่ม',
#  'กัลยา ดังอุโฆษ',
#  'กระเษม ใจเสือ',
#  'กู้เกียรติ ศรีวิไล',
#  'กรุณา โมระ',
#  'โกวิท กิตติวิบูลย์',
#  'กฤษณะ รักษากิจ',
#  'กัลยา ลิ้มสวัสดิ์',
#  'กรรณิการ์ ศิริเรือง',
#  'เกี่ยว วิมลเกียรติ',
#  'กรกช คำฟู',
#  'โกสุม โมมินทร์',
#  'กรรวี แช่มประเสริฐ',
#  'กวี นนทเปาระยะ',
#  'โกสินทร์ เตชะตน',
#  'กอปร์ชัย โพชากร',
#  'กฤษฎา วงศ์สง่า',
#  'ไก่แจ้ แซ่ตั้ง',
#  'กรรณิการ์ ดำรงวุฒิ',
#  'โกศล กานกายัน',
#  'เกศกนก ปิ่นปัก',
#  'เกรียงไกร เสือคง',
#  'กรรณิกา โกยสมบัติ',
#  'กำจร คำหมู่',
#  'กาญจนวรรณ ออมสิน',
#  'กาว หล่ายบุญ',
#  'กูลเสวก เสวกวรรณกร',
#  'กัญญา สิงห์สาหัส',
#  'กุลภัศร์ ดาวกระจ่าง',
#  'กฤติยา บุษปฤกษ์',
#  'กัลยา แสงงาม',
#  'เกษรา คริสโตแฟร์เซน',
#  'กำธร หาญสุรินทร์',
#  'การะเกด วงศ์วิเชียร',
#  'กอบกุล มากพูน',
#  'เกตนิกา ปัญญาหาญ',
#  'กมลพร โพธินันทะ',
#  'กฤษณะ เขียวปั้น',
#  'กิตติ กมลสันติสุข',
#  'กรรหาย',
#  'กฤตวรรณ ธีรพงษ์',
#  'กมลฉัตร โกมลดิษฐ์',
#  'กุลวดี เอี่ยมสมร',
#  'กิตติก้อง เมธารมณ์',
#  'กรกันยา เตชะมนูญ',
#  'ไกรรุจน์ ศรีเมือง',
#  'กฤษฎา เถามุ้ย',
#  'แก้วประไพร เกตุปิ่น',
#  'กฤษณ์ เติมศรี',
#  'กาญจนา พวงมณี',
#  'เกศรา เปรมมะ',
#  'กานต์ อัครวิวัฒน์',
#  'กิมไล้ ชาครีม',
#  'กูลศักดิ์ อยู่สุข',
#  'โกวิท ศิลานนท์',
#  'กาญจนา สมัคราช',
#  'กานดา รังสิมาวงศ์',
#  'ฤกษ์ แสงสระคู',
#  'กฤษฏ์ สุวัฑฒนะ',
#  'เกศเมือง เรืองศรี',
#  'เกษณี ตนภักดี',
#  'ไกรศรี แสงสวัสดิ์',
#  'กิตติ เฮี้ยนชาศรี',
#  'กระบี่ สุขสัจจี',
#  'กนกศักดิ์ สุวรรณชื่น',
#  'ก่อธิติ จำเริญศรี',
#  'กัณทิมา ทัศกลิ่น',
#  'เกรียงไกร สุรินทร์ตา',
#  'การีม โพธิ์ทอง',
#  'กาญจนา กันธะเสน',
#  'กิมไล้ ศรีกิจกุล',
#  'เกษร หวานแก้ว',
#  'กมลรัตน์ กมลพิมาน',
#  'กระจ่าง เผ่าประเสริฐ',
#  'เกื้อกูญช์ บุญเกิด',
#  'ไกรทอง ช้างน้อย',
#  'เกณิกา ขุนจันทร์',
#  'โกวิทย์ เรืองศรี',
#  'กอบแก้ว เถื่อนทับ',
#  'กิตติยา น้อยสินธุ์',
#  'ก้องเกียรติ คำคง',
#  'กิตติพล พิมพ์สวัสดิ์',
#  'กาหลง ดีมี',
#  'กนกวรรณ สุขสมชิต',
#  'กฤตยวัฒน์ ไชยรัชต์',
#  'โกมล นิลวงค์',
#  'ก้าวเฉียง',
#  'กำธร สมุทรสินธุ์',
#  'กีรติ เมืองมา',
#  'กงกช สุขประเสริฐ',
#  'เกศินี สุหัสปรีชา',
#  'กติกา มูลโพธิ์',
#  'เกษร บัวทอง',
#  'กฤษณา หางแก้ว',
#  'เกรียงเดช อินขลิบ',
#  'เกรียงไกร สุขแจ่ม',
#  'กมล บุญยะโภคา',
#  'กมล เหวียน',
#  'กาเส๊ะ สือนิ',
#  'กรสุก ชินธนาวัน',
#  'กาญจนา ยอดฉิมมา',
#  'กิตติมา เคส',
#  'โกงกิน',
#  'กิตติ เมฆศรีวรวรรณ',
#  'กรรณิกา บัวบึงงาม',
#  'กิ่งดาว สอนบุญลา',
#  'เกษร แสงทอง',
#  'กัลยา พันธ์สวัสดิ์',
#  'กมล เกิดโภคา',
#  'กฤษณะ หลักคำ',
#  'กัมพล ชัยจำรัส',
#  'กิตติพิชญ์ วัดน้อย',
#  'กฤษณา อยู่เกตุ',
#  'กัญญาณัฐ อมรเทพ',
#  'กนกกานต์ ใหมอ่อน',
#  'กาญจนา ฉิมพาลี',
#  'กู้เกียรติ ดิษฐปัญญา',
#  'กนิษฐา ปวะบุตร',
#  'กาญจนา หวานชิต',
#  'เกษร ศรีเปารยะ',
#  'การถอนญัตติ',
#  'การหมุนแบบฟาราเดย์',
#  'โกมลกล้า แก้วคำผา',
#  'กฤษณะ เสมาทอง',
#  'กุศล กระแสสินธุ์',
#  'กานดา ลิขิตรานันท์',
#  'กฤษณา แสงรอด',
#  'กนกรัตน์ สิงห์สมาน',
#  'เกรียงไกร ขันตี',
#  'กรรณิการ์ อิษวาส',
#  'กนกวรรณ วงศ์สวัสดิ์',
#  'กนกพร เปี่ยมสุข',
#  'แก้ว โกมาสถิตย์',
#  'กุหลาบ โต๊ะทอง',
#  'เกศสุดา เดชะคำภู',
#  'ไกรศรี แก้วเกตุ',
#  'กานต์ชนก เปาริก',
#  'กนกกชวรรณ แซ่เฮ้ง',
#  'กมลพร จันทร์ปรง',
#  'โกวิท นีละไพจิตร',
#  'การอุทิศ',
#  'กชกร อาจสามารถ',
#  'กัลป์ สุขสมไทย',
#  'กานดา สุขสมบูรณ์',
#  'กัลยกร สอนใจ',
#  'กัลยา ใจกว้าง',
#  'กรองทอง แซ่ตั้ง',
#  'กัญญารัตน์ พิมพ์ศิริ',
#  'เกษณี เทพวงศ์',
#  'กุหลาบ บัวเกตุ',
#  'กรรณิการ์ มอญขาม',
#  'กลีบ ขุนโต',
#  'โกวิทย์ เมืองศรี',
#  'เกษลิน แก้วโกมล',
#  'โกสุม บานเย็น',
#  'กาญจนา คำสุ',
#  'แก้ว เขื่อนแก้ว',
#  'กัลยา มุรีชน',
#  'กรรณิการ์ วงศ์สอน',
#  'กาญจนา ดวงตาเสือ',
#  'เกษม แค้นไธสง',
#  'กรณ์ บวรกิจรุ่งโรจน์',
#  'กัญญณัช เทพาวัฒนาสุข',
#  'กิจจา สมสวัสดิ์',
#  'เกรียงศักดิ์ ยอดยืน',
#  'กังสดาล หุ่นแสน',
#  'กรวรรณ ชิคาตะ',
#  'กรุณา เยี่ยงแก้ว',
#  'กาหลง เบญจมินทร์',
#  'กมลชนก ยืนยงค์',
#  'กุลวดี ศิวิลัย',
#  ...]

# %%
from jiwer import cer

# %%
cer(test_target_texts,pred)
# Out:
# 0.32927615571776153

# %%
pred
# Out:
# ['กัลยา จันมูลุน',
#  '๙านต์ ',
#  '8กรสร มูลผึ้ง',
#  '๙นกทิพย์ ',
#  '!ระปูกกลุก',
#  '๙กณิกา คูโรดา์',
#  '๙มล ',
#  '๙านทิชา จักตรี',
#  '๙าจ ',
#  'กรวิกา สหัสจารย์',
#  '8ุหลาบ บัวอิน์',
#  '๙รรณิการ์ ',
#  'ๆอบกุล อิงคุทานนท์',
#  'ๆุสุมา พลทุกข์',
#  '8ฤษณ์ กิติโก',
#  'ๆิตติ ตรง',
#  '8ลิ่นทิพย์ พิมพ์',
#  '!กนกล้วย',
#  'กฤติน ติลกานนท์',
#  'กระจ่าง ชอปรุ',
#  'กุลชง จุฑานิตย์',
#  '๊ำแพงผาษี',
#  'กฤติยา สุทธากุล',
#  '8กรสิงห์ ชินพระวอ์',
#  '6กษร กาปัญญา',
#  'ๆร รรังรัก์',
#  '๙กียรติภนม ซอมพิลา์',
#  '8ุหลาบ ',
#  'ััลยา ',
#  '8กียรติการ์',
#  '๙นกพร รังสม',
#  'ูุลิสรา อรุณแสงง',
#  '๙กษรี ดีประดับ์์',
#  '8ฤษณ์ สุจิทธาระกูล',
#  '๙ิตติคุณ ตั้งสีวงศ์ง',
#  '๙ันตภร อ่วมสะอาด',
#  '๊กวิท มาลัยศิริรัตน์์',
#  '๙มลวรรณ มีพันธ์',
#  'กวีพจน์ การะ',
#  'ฤฤษณะ จันทร์แก้ว',
#  '๙ก้ววันดี ผาพูมิ',
#  '8รี',
#  '๙นก บุญยรัต',
#  '๙ก้วตา ',
#  '8ุหลาบ หมอนาค',
#  '8กล้รุ่ง บุญชก',
#  'ััลยา ',
#  '๙ิตติโชติ ทัพวงศ์ง',
#  '๙ารแพด',
#  '๙ะ',
#  '8กรียงศักดิ์ ชูมณี',
#  '6กศรี ตระงั่นซี',
#  '๙มลวรรณ ',
#  '8กล้รุ่ง แดงหิรัญน',
#  '6ก็บ อำไพ',
#  '๙นกวรรณ ',
#  '6กษม กุฎีราช์์์',
#  '๙ารคลาย',
#  'ััลยกร วีระ',
#  '๙รรณิการ์ น้อย',
#  '6กศกนก คำชะ',
#  '6กษทิพย์ ศุภวาิช์',
#  '6กษร จาบพลัน',
#  '๙มลฉันทร์ มีแสงง',
#  'กรุณา พึ่งรัตนะ',
#  'ๆรองแก้ว อุตสา์',
#  '๙นกอร พลบุญ์',
#  '๙มล สังข์สุข',
#  'กิติพงษ์ ',
#  '๙รรณิการ์ ไหววงศ์',
#  '๙ก้ว จันมา',
#  'ๆิตติภูมิ ',
#  '๙มลทิพย์ ',
#  '๙มล คงด้วยแก้ว',
#  'ๆำพล ',
#  'ๆิติศักดิ์ ดิษกร์',
#  'ๆิมพิง แซ่อึ้ง',
#  '๙นกวรรณ ทำศรี์',
#  '๙านดา คำคงสาตย์',
#  '๙า',
#  '8ิ่งกานต์ สว่างศรี',
#  'ฤฤษณะ ปรีชาชาติ',
#  'ๆุสุมา บุญลอย',
#  '!กล็ด',
#  '8ิ่งแก้ว แซ่อื้อ',
#  '๙กษม พวงมณีี',
#  '๙าน',
#  '๙่อ',
#  'ๆุ่โฮ้ แซ่จึง',
#  '๙กียรติศักดิ์ ศิริ์',
#  '๙าญจนา ',
#  '6กศินี สุวสรรภรณ์',
#  '8ุลปราณี อาจมิมานะ',
#  '8ุลพงศ์ อ่อนมณี',
#  '8ุลมณี ทีฆะยศ',
#  '๊่อบัว ',
#  '๙ก้วดี พรหมฟัง',
#  '๙ันยารัตน์ ทอง',
#  '๙นกรัตน์ ประสพ',
#  'กำหนาด',
#  '๊วี จันสา์',
#  '8รุง กรุตาชา์',
#  '!กร',
#  'ๆอบศักดิ์ จินตกานนท์',
#  'ฤฤษณะ โอภาส์',
#  'กฤติศักดิ์ สาสนากุล',
#  'กฤษณพร ',
#  '๙อบุญ มาจุฬา',
#  'ๆำพล ยอดนนท์',
#  '๙นกพร มากรนาน์',
#  '๙กวิทย์ วิชัยจิตต์',
#  'ๆิตติ',
#  '๙นกพรรณ โลหะ',
#  '๙ิตติพงษ์ ',
#  '8ุศล แซ่อึ้ง',
#  'ััลยา ',
#  'ฤกษ์ชัย สุขสำราญ์',
#  '๙ารทำสมาธิ',
#  '8กรสร ผสมทรัพย์์',
#  '๙ารสีนี',
#  'ๆัณหา ',
#  '๙ิตติพงษ์ ทาพันธ์',
#  '๙นกอร ศรีสุกใส',
#  'กรวิกา วงศ์ภาพ์',
#  'กระ',
#  '๙ุลนิษฐ์ นันทะแสน',
#  '8ฤษณ์ บุญนิธิ',
#  '๙ารแข็งขัน',
#  '6กษสุดา กุล',
#  'ๆำพล แสงสุข',
#  'ๆำจัด การขุนทด์',
#  '!ล็อบ',
#  '๙ิตติพร บุญพามี',
#  '๙นกวรรณ อ่วมสอน',
#  'กรวิทย์ โตใหญ่',
#  '๙กษม ศิริ',
#  'ๆองกาญจน์ สิงห์สมดี',
#  'ๆิตติโชติ บุรีราษฎร์',
#  '๙นกนุช หลักฐานดี',
#  'ๆิจจา พิมพ์ทอง',
#  'กฤษณะ ณรงค์ศรี์',
#  '๙รรณิการ์ ศรีประ',
#  'กวินธิดา ศิริ',
#  '๙มลทิพย์ ชูสี',
#  'ๆิตติคุณ คงอยู่',
#  'ฤฤตยา วันชื่น',
#  'กรุณา ',
#  'กกกลุม',
#  '8ุหลาบ จันทร์แก้ว',
#  '๙นกอร พูลพิพัฒน์',
#  'ๆิมไล้ ปฏิทัต์',
#  'ๆร รอดทอง',
#  'ๆองแก้ว ววังบุญ',
#  '๙ัญญา มาคต',
#  'ััลยดา สิน',
#  '8ฤตภัค ศรีสะอาด',
#  'ััณฐา',
#  'ๆิจดา ',
#  '๙ิตติคุณ อุมาสา',
#  '๙กศรา สง่ากองง',
#  '๙ินนารี ชนะสิทธิ์',
#  '6กษม นินาจปัญญา',
#  '8กรียงศักดิ์ คงคาดี',
#  '๙ิตติ คำพร้อม์',
#  '๙ก่นแก้ว ปัญญาา',
#  '!รมมุรพ',
#  '6าย คงโต',
#  '๙าญจนา รสนนท์',
#  'กรกมล สุขแก้ว',
#  '6กษา สุขสมสสต์',
#  '๙กษม แป้นคำ',
#  '๙าหลง พล',
#  'กฤตยา ศรีสันติสุข์',
#  'ๆิมง้วน แซ่อึ้ง',
#  'กิติมา ไทรนุ้ย',
#  '8ฤษณ์ จิตนุยานนท์',
#  '8ุลจิรา ชัยวิจิตร',
#  '๙กษม ลาดสะอาด',
#  '๙กษม โลชะยะ',
#  '6กษร อธิพจน์',
#  '8กร',
#  'ๆิตติธัช บุญชาโด',
#  'ๆองสี งอกไพ่',
#  '๙ิติพร คงสมัย',
#  '๙ารบูรณาชรบต',
#  '๙ายวัน หมื่นบุญมี',
#  '๙ัญญา อนันตชาติตร',
#  '๙ิตติรัตน์ ชาติไทย',
#  'กุลวดี รักการดี',
#  '8ริชชัย พลาวาสุ',
#  '๙รรธร ท ทศนาศร',
#  'ๆิตติ บุญประกอบ์์',
#  '8ุหลาบ ',
#  '๙ันตภร โชติชัยศรี์',
#  '๙มล พันธ์พลสินุ์',
#  '๙นกวรรณ มุสตอฟาดี',
#  '8กรียงศักดิ์ ชู',
#  '๙มลกาจ รุ่งปิน',
#  '๙าญจนา แซ่จัง',
#  'กฤติยา ',
#  '8ารุณ วาหา',
#  '๙ัตติกา สลัก์',
#  'กนิษฐา กิจสมบัติ',
#  'กษมน ภูมิวาสนะ',
#  'ๆ๊อด ',
#  '๙กษม วีระจุน์',
#  '๙นกวรรณ ชมพงษ์ง',
#  'กิตติ',
#  'ๆิตติศักดิ์ ไชยรส์',
#  'ฤฤษณะ บุญชัย',
#  'ฤฤติดา ปริยพันธ์',
#  '๙กวิท พัดพิทักษ์',
#  'ๆิติภูมิ จิตกุศล์',
#  'กีรติยา มาลาไสย',
#  '6ุลนิต ',
#  '6ุลชลี ดารากามาศ์ต',
#  '๙กษมสันต์ คงจันทร์',
#  'กษิณะ จันทร์งาม',
#  'ๆิมไล้ มงคลสืบ',
#  'กมลวรรณ พันธ์',
#  '๙าญจนา ใจหลังกา',
#  '๙ุลยา พิสิษฐ',
#  'กลิ่นสุคนธ์ แสงแก้ว',
#  'วงตอง',
#  'ๆิมล้วน ',
#  '6ชกร ',
#  '๙าญจนา ฮวบสกุล',
#  'ััลยา พาดพงษ์ง',
#  '๙ารรับรอง',
#  '6ุลชวี กำไชยภัย',
#  'กีรติ บุญสิน์',
#  '๊กไซย สุวรรณวัฒน์',
#  '๙าญจนา กันทะคำ',
#  'ๆกมินทร์ ชุ่มชื่น',
#  'ฤฤติยา ปัญญานนวัฒน์',
#  '๙านดา แกล้กล้า',
#  '๙มลทิพย์ สยอมใจ',
#  'ััลยาิตร มีแสง',
#  '๙นกวรรณ สุมาลัย',
#  '๙นกวรรณ วิสิษฐานนท์',
#  '๙ัญญา ดวงปินตา',
#  'กิติยา วารีดีี',
#  '8กร',
#  'กัลยา พรหม',
#  '8กรียงศักดิ์ กกกมาศ์',
#  '8กรสร ศรี',
#  'ๆิตติ สนใหม่',
#  '!ลอ',
#  '๙านต์ พงษ์มาลา',
#  '8กรสร อ่อนหวาน',
#  '๙มล ธัญสุวรรณ',
#  '๙าญจนา วาสิกศิริี',
#  'กัญญา ',
#  '๙ก้ว จันทะไพจิตร',
#  'ๆิตติ โพธิ์สุข',
#  '๙าญจนา ',
#  'กรปัต นิลพยัคฆ์',
#  'กมลมัลย์ หงษ์ภักดี',
#  'ๆิมกี ',
#  '8กรสีห์ ',
#  '๙นกวรรณ รัตนะ',
#  '๙าไนย์ แซ่ตัน',
#  'กรปณต แก้วบัวดี',
#  'กัลยา ซือ',
#  '๙กษศิริ แตงโสภา',
#  '๙ำไร สุขปรุง์',
#  '๙ัญญาลักษณ์ จิตสุข',
#  '8ิ่งกมล ใจใส',
#  'ๆิตติ กฎหนัน',
#  '๙นกอร อิทธิลับ์์',
#  '8กรสร นาคประดิษฐ์',
#  '๙นกวรรณ ฟริดแมน์',
#  'ๆิตติ โพธิ์นุสิทธิ์์',
#  'ๆิตติพงษ์ นาคสุสุข์',
#  '8กรสีห์ อภิชัย',
#  'ััญชลา นาประ',
#  'ๆอบกุล ศรีชุม',
#  'ๆร ชีนมะ',
#  '๙าสกร ฮวบวัน',
#  '๙ันต์ชัตร สุขดี',
#  '8ฤษณ์ แครัช์',
#  '๙รินทร์ ชาลิสราพงศ์',
#  '6กษร งามฉวีพันธ์',
#  'ๆิตติ กราบนานนท์',
#  '๙าญจนา พงษ์ประยูร์',
#  '๙ัญญา ',
#  'ๆำพล ประวันนะ',
#  'ๆิม',
#  '๙รกฎ แมนซีสม',
#  '๙ัญญา พูลทวี',
#  '๙รรณิการ์ ธีระพงษ์ง',
#  '8ชพรรณ ',
#  '8กรียงไกร กอ',
#  '๙รรณิการ์ จันติ๊บ',
#  '8กรศักดิ์ แช่มพล',
#  '!ก็บกฎ',
#  '๙านตะพงศ์ ฟัก',
#  '6กษร มีปัญญา',
#  'ๆิจจา วงศ์จินดา',
#  'ๆก',
#  'ััลยกร ',
#  '๙รกราน วิชัยธรรม',
#  'ๆำไล ปราบงู',
#  'ฤฤษณะ ร้อยกรุด',
#  '๙นกพร บุญญาภพ์์',
#  'กัลยาณี บุญยะ',
#  'ฤฤษณะ โพธิ์ประทับ์',
#  'ๆุ่บ๊วย ',
#  'ฤฤษณะ ภมรสูต์',
#  'กัลยา ชาดอก',
#  '๊วี สุขพลศรี์',
#  'กัลยาณี โลลาไมม่',
#  '๙านต์ ปลุกใจ',
#  '๙าญจนา หุ่นวงศ์ธรรม',
#  '6กษร สาวนายน์',
#  'ๆิม',
#  '๙าสรนะ โพธิ์ชันทร์',
#  '๙รรณิการ์ จินตวร์',
#  '๙กสรา ',
#  '8กรียงไกร สัง',
#  '๙านต์ โอทอง์',
#  '8กรียงไกร ',
#  'กฤษฎา ',
#  'ฯายภาพบำบัด',
#  '๙ันยารัตน์ โพนทอง',
#  '๙มล ใจยิ่ง',
#  'ๆัมปนาท พรหมมาก',
#  '๙มัน์',
#  '๙ารุณ ',
#  '๙มล กาจู',
#  '๙นก สุวรรณรังสี',
#  'ๆิตติ ไพ',
#  '๙รวีร์ โลสิงคำ',
#  '8กรียงศักดิ์ ',
#  'กฤติยา วงค์ที',
#  'ๆอบศักดิ์ นิมมอนงค์งง',
#  'ๆิตติศักดิ์ ทิวะ',
#  '8ุศล สบุแก้ว',
#  '8รีสสธรรม ธูปบูชา',
#  '6ุลนิต สุนทรโอภาส์',
#  'กตัญญู โกมุทมาศ์',
#  'กรุณา กอคัน์',
#  '8ุหลาบ มะ',
#  '6กศินี ',
#  '๙าญจนา พรราชม',
#  'ๆลวรรธน์ อรัญน',
#  '๙าญจนา สานติศักดิ์ก',
#  '๙ิจสกร กล้ากาสิกิจ',
#  'ๆำพล มหา',
#  'ๆำพล มานะสุข์',
#  '๙รรณิการ์ มูลทรัพย์์',
#  '8กรสีห์ ',
#  '๙าหลง ซอนสุข',
#  'ฤฤษณะ ',
#  '8ุลนที แจ้งกรน',
#  '๙กษวดี แก้วสุวรรณ',
#  'กาหลง ยอดทอง',
#  '8ฤษฎา ปาลกะวงศ์',
#  'ััลยา ปานฟัก',
#  'ๆิมลี้ จันพุฒ',
#  '๙ารติดต่ำต่อ',
#  'ๆกมล สุข',
#  '๙ิตติพัฒน์ โพธิ์ภูมิ',
#  '6ี กิบซิน',
#  'กนิษฐา แก้วไหล',
#  'ๆิตติ ไชยยนบุญูลย์',
#  'กรประ',
#  'กรชนาด ร่มโพธิ์ใหญ่',
#  '๊ิมโหง แซ่ลี้',
#  'ๆำพล สุริโย',
#  'ััลย์สุดา ทองมาก',
#  '๙กดำ',
#  '๙าญจนา กุดละา',
#  '๙าญจนา ดับมหาราช์',
#  '8ุลริศา สองแสงง',
#  '๙นกพร ',
#  '8ิ่งกาน อุบลไชย',
#  '๙ก้ว สมพร์',
#  'กฤษฎา ไห้โศก์',
#  'กฤษณะ ธรรมโกาะ',
#  '๙าญจนา ทากระ',
#  '๊ษมา ',
#  'กวีพันธ์ แสงสุข',
#  '๙ัญจรัต ไทยยันตต',
#  '6กษณิวัลย์ ถูกจิตต์',
#  '๙นก กาญจนพันธ์',
#  '๙กษม อินทสังข์',
#  '๙านต์นัดดา คุณหอม',
#  '๙านดา ',
#  '๊ิมโหง รตะสุขารมณ์',
#  '๙นกวรรณ กิจนวศินุ์',
#  'ๆิตติ สุวรรณวิจารย์',
#  '๙ิตติชัย แซ่ตัน',
#  '๙กษม ศรีสุวรรณ',
#  'กวยตั้ง แซ่ตั้ง',
#  '๙นกวรรณ ศรี',
#  '6กียน ไทยมานิตย์',
#  'ๆุสุมา นิลานิยม',
#  '๙านดาภา ชีนวิทย์',
#  '8กรียงศักดิ์ อินทะสา',
#  'ๆอบกุล ววัง',
#  'ฤฤตยา คงคามาศ์',
#  '๙ารันต์ ปุ่นศรี',
#  'กลรัศ ',
#  '๙ิตติพงษ์ กันงาม',
#  '๙าญจนา ตีรพัฒน์',
#  'กกนซิทธิ',
#  '๙รรณิการ์ ดอนหลักคำ',
#  '6กษร ศิลออาด',
#  'ๆิตติคุณ ปันตากั่ว',
#  'กนวี ผิวนวล',
#  '8กรสร พรรณาาา',
#  'ฺันยกร ลล้าสุนนท์',
#  'ฤฤษณะ ดังควาดหน้า',
#  '๙กษประทุม บุญญาธิ',
#  '๙ารแบ่งปัน',
#  '๙กศล สุทธินร',
#  '6กื้อ ผกาแก้ว',
#  'ๆุ้ย',
#  '๙นกพร พุกพันธ์',
#  'ฤฤษฎา หนูรักษ์',
#  '๙รรณิการ์ ทิทธิธรรม',
#  '๙กาะกุม',
#  '๙านต์นิสา สุดขยัน์',
#  'ฤฤษณะ วันทนากุล',
#  '8ิ่ง สุขสวัสดิ์',
#  '๙กษม อิน',
#  '๙มล อุ่นแก้ว',
#  '๙านต์ ขวัญ',
#  'ััลยา ',
#  'ฤฤษณะ คลองลาวา',
#  '๙าญจนี สุนาลัย',
#  '6กศกนก มันทิม์ม',
#  'กีรติ ชัยยิ้มวงศ์',
#  'กิรณา ',
#  'กิต',
#  '๊กวิท ราชฎร์รัตน์',
#  'ฤฤษณะ พรมตตื้อ',
#  'กฤศนัท ช่วงถึก',
#  'กฤษฎา ผาสุขดี',
#  '!ว้างมา',
#  'กรกนก ',
#  '๙กษม ลิ้มวงศ์',
#  'กฤษฎี ปริวัตกุล',
#  '๙กษม จินดาวงศ์',
#  '๙กศล รังสิมันวงศ์ง',
#  'ๆังวาน ',
#  'กุลวดี สมยาดี',
#  '6กษร สุจริต์',
#  '6ุลชลี รุ่งสว่าง',
#  '๙ก้วนภา ทองหวาน',
#  'กรวดี ',
#  'กัลยารัตน์ วิกา์',
#  '8กี๋ยง แจ้ง',
#  '๙ารคาดคะ',
#  'ๆอบ ศักดิ',
#  '8กรวุฒิ จิรบุตร',
#  '8รุย',
#  '8ฤษฎา นวลจันทร์',
#  '๙นกวรรณ ซีม่วง',
#  '๊กวลี ศรีบุบผา',
#  '๊กสินทร์ ด่านพิทักษ์',
#  '๙มล ',
#  '๙ารค่ความ',
#  '6กตุคณี บัว',
#  '๊ำ',
#  '6ชพงศ์ แสงทองง',
#  '!ังกา',
#  '๙กวิทย์ ผาสุขมูล',
#  '6กื้อกูล แสนทอง',
#  'ๆิตติชัย ไกรจิตต์',
#  '๙กศล จันทองง',
#  'ๆิตติศักดิ์ อ่นทอง',
#  'ฤฤตยา ตัน',
#  'ๆัณหา ',
#  '๙กศล ชันโอภาส์',
#  'กรกฎ ชัยชมภู',
#  '๙รินทร์ มณีวรรณ',
#  'กรีตอน ววานกามา',
#  '6กศินี ',
#  'กฤษฎา ดวงกุศล์',
#  'กฤษฎา ',
#  'กฤษฎา วรงาม',
#  '8ฤษณ์ มานะวิทย์',
#  'ฤฤษณะ กุลรอด์',
#  '๙าญจนา ขาวประ',
#  '๙กษม สินธร',
#  '๙ก้วฤทธิ์ คำบุญยอะะ',
#  '๙าญจนา ลือดัง์',
#  '๙านต์พิชชา โอสาไว์',
#  'ๆิตติ ชัยสีทา',
#  '๙รรณิการ์ อยู่ส่ง',
#  '๙าญจนา ปาละ',
#  '๙าญจนา นิ่มนวลดี',
#  '๙กษณี บุญชม',
#  'กวิสรา นิยกิจ',
#  '๙มลฉัตร ทูมวงค์',
#  '8กริกฤทธิ์ ไชยมาตย์',
#  '๙ิตติมา อินทลาภ์์',
#  '๙มล ',
#  'ๆิมม สิทธิกรณสกุล',
#  'กัลยาณี งามทิพย์',
#  '8กรสร ปิง',
#  'กรวรรณ แก้ว',
#  '๙ัญญา พลจันทึก',
#  'ๆิตติ ขวันมงคล์',
#  'ๆำธร นามบันนนท์',
#  '8ิ่งกาน ศรีวิไล',
#  '๙กษสินี แซ่ตั้ง',
#  '8ุหลาบ ศรีวิโรจน์',
#  'กฤษฎา ตระกูลโอสถ',
#  '๙านติภา แซ่',
#  'ๆิจจา แซ่จิว',
#  'ะวว',
#  'กัลยา คำบุญทา',
#  '๙กษแก้ว สืบสาย',
#  'กฤษฎา สอนไหว',
#  '!ล้อง',
#  '๙มล การสม',
#  '๙กษตร ภู่ขาว',
#  'กิติธัช ปรุง',
#  'กนิษฐา นันทศิลป์',
#  '๙มลพร พลวิทูรย์',
#  '๙ิตติมา ',
#  'ๆรองทอง ',
#  '๙นกวรรณ กัลยา',
#  '8ุหลาบ ',
#  'ๆุสุมา ',
#  '8กรียงไกร ทิพย์โสภา',
#  'ฤกษ์ชัย พีรพงษ์ง',
#  'ฤฤษฎา ฮา',
#  '๙นกวรรณ นกแก้ว',
#  'กมลวรรณ ',
#  '๊กวลี ทมขาพานิช์',
#  '๙มลกร สว่างศรี์',
#  '๙ิตติพงษ์ แซ่',
#  '6กษร สร้อยสุวรรณ',
#  'ๆำธร บัณฑุวงศ์',
#  '๙มลชนก ทวีทรัพย์',
#  '๙าญจนา ',
#  'ััลย์พัสร รุจิโกไสย',
#  '๙นกวรรณ ลลังอา์',
#  'ๆิติชัย ทองคอด์',
#  '๙าญจนา จุลนัย',
#  'กลิน กลิ่นหอม',
#  '๙กไซย ไพยทักษิี',
#  'กฤติยา มีสมศักดิ์ก์',
#  '๙กศล วรพุทธ์',
#  'กัลยา โต๊ะสะและ',
#  'ๆำพล พานิชวิบูลย์',
#  'ฤฤษณะ ไพรอานันต์',
#  '๙มล ตตติน์',
#  'ๆองพล ',
#  '๙ารพัฒนา',
#  '6กษร ',
#  'ๆรแก้ว กาญจโนภาส์',
#  'กะดู่หนอง',
#  'ฤฤติยา สินสมบูรณ์',
#  'กรกนก ชุ่มชาติ',
#  '๙ก้ว ',
#  '8ิ่งแก้ว ยืนยาง',
#  'ๆำพล หงษ์โตะ',
#  '8ุลดา ศิริวิญญานนท์',
#  '8รองจันทร์ สกุลยงค์ง',
#  '๙ิตติพร ไหววว',
#  '๙าญจนา โนน',
#  'ๆิตติ ฝาปากษิติ์์',
#  'ๆิตติพงษ์ ทองขาว',
#  '๙ันทิมา ',
#  '๙มล ภาสยะวัต',
#  '๙ิตติภพ บุญ',
#  '๙ันตินันท์ มูลทองฟักก์',
#  'กัลยา ภูสี',
#  '๙ัญญา นึกสมพงษ์ง',
#  '6กศินี ศรีชำนาญน',
#  'ๆิม',
#  '8ฤษฎา พล',
#  '6กษศิริ ปานทอง',
#  '๙าญจนา พุก',
#  '๙านต์ ถาวนนนพน',
#  '6กษแก้ว หงส์',
#  'การีม ทองหล่อ',
#  'กษมา วงศ์',
#  '๙ารกลาย',
#  '๙ัญญา ชัยรักษา',
#  '๙ก้วใจ พรหมบุตร',
#  'ๆิตติ หมื่นสืบ',
#  '๙ชพร ชลสุข์',
#  'ๆิจจาส แสงอรุณ',
#  '๙นกพร นกสกุล',
#  '๙มลวรรณ ดิษยบุตร',
#  'กัลยา มนพิพัฒน์',
#  '๙นกพิน ริดระยะ',
#  '๊กวกขขาม',
#  'ๆิจจา ณ',
#  '8ุล',
#  '6ชกร ซิมพิทักษ์',
#  '6าย อมตานิรันดร์',
#  '๙ารติความความใหม่',
#  '๙าญจนา สิกขชาติตย์ต',
#  'กิจพงษ์ ช้างยัน์',
#  'ฤฤษณะ วุฒิศิลป์',
#  'กรกฎ หัสดิน์',
#  '8ฤตพร โพธิ์ทอง',
#  '๙ัญญา สอนแก้ว',
#  'ๆิมกี สาดประ',
#  '๙กวิทย์ สุด',
#  'ๆิจ',
#  '๙ารุณ ศรีพาสรานุสรณ์น',
#  'ฤฤษณะ รักษาแดน',
#  '8กรยุทธ ',
#  '๙กษริน พันธวงศ์',
#  'กรวรรณ แซ่ลิ้ม',
#  '6ุลวิภา บุญทน',
#  '๙มล อำไพศิริวงศ์',
#  '๙ก่นจันทร์ ยินมะ',
#  '๙ำ',
#  'ััลยกร ข้อยุ่น',
#  '๙ิตติยา ศรีจันตาตา',
#  '๙ิตติภัค คาดคำ',
#  'กษมพงษ์ บุนนาค',
#  'ๆ้องภพ ชัยนากรบ',
#  '๙มล กันธิโกวิท์',
#  '!ระจอกนนีรภัย',
#  '๙าญจนา ศรีโกมุท์',
#  '๙าญจนา ศรีพิทักษ์',
#  'กระตืืรรือร่อน',
#  '8ฤตินี สิงหพันธ์',
#  'ฤฤษณะ กุลศรีรัตน์์์',
#  '๙นกวรรณ อรรกลา์์',
#  'ฤฤษฎา กังราช์์',
#  'ๆิตติพงษ์ ',
#  'กฤษฎา หนู',
#  'ะกลาย',
#  '๙าญจนา ทองรักษ์',
#  '๙ก้ว จันทร์มูล',
#  '8ฤษณ์ อนุตรกุล',
#  'ๆิตติ ',
#  'ๆกมิน บุญนาค',
#  'ๆุสุมา พรมพลินร์',
#  '6กษมศรี ไทยกล้า',
#  '8กรวัลย์ อินนาดอน์',
#  'กฤษณะ ชูทรัพย์์',
#  'ๆู้',
#  '๙ารบริหารที่มีชอบ',
#  '6กศจฎา สีติ๊บ',
#  '๙ัญญาภัค รูปิยาพร์',
#  '6กษร วาจานรชนะ',
#  'ๆกมล ',
#  '๙มลรัตน์ ผูสิงห์ง์',
#  '8ฤษฎี โสระไกร',
#  '๙มล ตีจรูญ์',
#  'ะ้อนักรี',
#  '๙รรณ์ทิพย์ ชีโมงค์',
#  'กินอัจชนะ นามโคตร',
#  '๙ิตตินันท์ ยืนยาว',
#  '๙านต์ พรหมสุวรรณ',
#  '8ชพรรณ คมานานุกิจิ์',
#  '8กรียงศักดิ์ ขุนจักร',
#  '๙กวิท ',
#  '๙กศกัญญาณี นฤไหา',
#  '๙านการันย์ ชอบจิต์',
#  'กิติยาพร สอนสุภาพ์์',
#  '8ุลสระ สนกุล',
#  '๙รอนงค์ วงศ์มณี',
#  '8กล้รุ่ง สุข',
#  '๙าร',
#  'ๆิตติพงษ์ สุดชาติ',
#  '๙ิตติ สารสิทธิ์์',
#  '๙ิตติคุณ ก้อนทอง',
#  'ๆกมล ',
#  'กฤษฎา บริสุทธิ์',
#  '6กโงอว แซ่นิ้ม',
#  '๙ำพร้า จินตรินทร์',
#  'ๆุตวดี ',
#  '๙ัญญาณี นาค',
#  '8ิ่งอำ',
#  'กฤษณะ พลมะทอง',
#  '๙รรณิการ์ ทอง',
#  '๙กียรติศักดิ์ วงไหว',
#  '๙ิตติ ตาลคำ',
#  '๙กษม จันทร์หอม',
#  '๙ัญญา พลรักษ์',
#  '๙นกวรรณ ปวนกุล',
#  'ๆอบ',
#  'ๆิตติชัย ลีกรันใจย',
#  '๙าญจนา กลับรอด์',
#  '๙ัญญา ',
#  'ฆษาตะภา คำมี',
#  'กฤษนันท์ ทัพพันธ์',
#  '8ุลชไม้ สหบุญกุล',
#  'กล้าหาน โซลี',
#  '๙าญจนา ',
#  '8รุงทอน ศิริอ่น',
#  '๙าญจนา ',
#  '๙าญจนา วิบูลย์ดน์',
#  'ฤฤษณะ วิชาพร์',
#  'ๆิมกี แซ่',
#  '๙รรณิการ์ ',
#  '๙รรณิการ์ ใจมิน์',
#  'ๆิตติพันธ์ กิตติ',
#  'ๆ้อง',
#  '8ุศล สมนึก',
#  '๙รรณิการ์ หวังโพคา',
#  '๙ษิดิ์',
#  '๙ารต่อม',
#  '๙กษม นาคลดา',
#  'กฤษฎา ใหญ่สุไร',
#  'กตัญญู จิตชื่น',
#  '๙านดา ศรีธารานนท์',
#  '๙กศล รักทองง',
#  'กรทอง ปานิกบุตร',
#  '๙านติพงษ์ วงล์ลอ์ะ์',
#  'ๆัมปนาท มินกูล',
#  'ฤฤษฎา ชะบา์',
#  'ๆองชุน มีมาจำ',
#  '๙ก้ว สุวิี',
#  '8ฤชกร วงศ์ไทย',
#  '๙าญจนา ทองสิงห์',
#  '๙าญจนา กา',
#  'กฤษณะ แสนคำ',
#  '๙กะ อ่วมสวัสดิ์',
#  'กฤษณะ จันทะกอ์',
#  '๙ก้วดี ทนันชัย',
#  '๙าญจนา ภูยานนท์',
#  '๙กมล รอดทับทิม',
#  'กิติยาดา ปริณารัมย์',
#  'กิรณา ',
#  'ๆิตติ วงค์จินา',
#  '6ก่งจกาจ สว่างศิลป์',
#  '๙มลทิพย์ รำ',
#  '๙ิตยาภรณ์ แก้วมณีี',
#  '8ชพรรณ บวรวานิช์',
#  'ๆัณหา วงศ์ทิพย์',
#  'ๆิตติ ยกพ่วง',
#  '8กรสีห์ อาชามาศ์',
#  '8ิ่งกาน ',
#  'กรชนก ฉิมจันทร์',
#  '๙ิติภพ ซีหานน',
#  'ๆิติโพธิ์ ชาติชัย',
#  '6ชกร มมิแตร',
#  'ขวิตา แจ้งสว่าง',
#  '๙าญจนา หาริดวงศ์',
#  '8ลั้น สุขประ',
#  '8รองใจ บินโรสลลาน',
#  'ๆอบกฤษ โมราศิลปินร์',
#  '๙นกพร วรอุไร์',
#  'ๆังวาน ',
#  'กรุณา อิศรางกูร',
#  '๙นกวรรณ รักแจ้งง',
#  '8ิ่ง แต้ม',
#  'ๆำพล ฉันทวิบูลย์',
#  'กฤษณานันท์ ยั่งน้อย',
#  '๙มล ',
#  '6กษริน ฉิม',
#  'กุลวดี ตันทะ',
#  '๙มล สุขคำ',
#  '๊่อพงศ์ อิ',
#  '๙ก้วลูน บุญลอย',
#  'กวิน สุปินะ',
#  '8ิ่ง สุคันธะ',
#  '๙นกวรรณ แซ่',
#  'ลหลือบจม',
#  '๙ิตติรัตน์ ',
#  '๙กวิทย์ ลาภพระบุตร',
#  '6กศินี ',
#  'กุณายิน แซ่ลี้',
#  '6กษร ',
#  '๊ลล',
#  '๙านตยา กิจสวาท์',
#  '๙ันตินันท์ สุขกล่ำ',
#  'กิจวดี สงวนศักดิ์ก์',
#  '๙กวิท พลันใจ',
#  '๙กษชัติพี ช้างศรี',
#  '6กษร ธรรมชีวัน์',
#  'ๆำมะหยี่ สินธุสาร์',
#  '๙มล โกศลสุวิวัฒน์',
#  '๙นกวรรณ ฤกษ์ถนอม',
#  'กฤษณะพงษ์ สุภาพ์์',
#  'กรุณา ',
#  'ๆิตติ ทัพ',
#  'ๆิจชัย ทองคู่',
#  '!รรมมา',
#  '๙านตยา หิน์',
#  '8ิ่ง',
#  'ๆิมยับ ',
#  '๙าญจนี กุลสุรกิจิ',
#  'กฤษณี ศิวารินร์',
#  '๙นกวรรณ ไทย',
#  '4วิน ',
#  '6กษมวิทย์ โลหิตกุล',
#  '6ุลธิดา ใบลาภ์์',
#  '๙มลทิพย์ ธรรมวัฒน์์',
#  '๙าญจนา อุ่ใน',
#  '๙าญจนา น้อยวงศ์',
#  '6กษมศรี ',
#  'ๆิตติพงษ์ วานิช์',
#  '8ิ่งกาน ',
#  'ัันยารัง',
#  'กฤษฎา รอดกลิ่น',
#  '๙กษม ไกรภู',
#  '6กษแก้ว อึ้งสาย',
#  '๙มล สุขสมมม่',
#  '8กรียงศักดิ์ จันทองง',
#  '8กรทูน สุขสนใจ',
#  '๙ิตติพร วงศ์อินทร์',
#  '8กรียงศักดิ์ การภัยรี์',
#  '๙ิตตินัย ปิติพาส์',
#  '6ุลนิวัตร์ กุลภัยบุตร',
#  'ๆอบพงษ์ นามสง่า',
#  '๙มล แซ่',
#  '๙ารผสมกลมกลืน',
#  'กาลสิน โยธิ',
#  '๙ก้ว แสงสมรส์',
#  '๙ก้ว ยอดคำ',
#  '๙ันทิมา ',
#  '8ฤษฎา มณีคันธ์',
#  '๙กล้า กุโบลา',
#  'ๆิตติศักดิ์ พวงพูน',
#  '๙ารน้ำไฟฟ้า',
#  '๙าญจนี บุญมาก์',
#  '6กษแก้ว ลูก',
#  'ๆร ชูรัตน์',
#  '๙าญจนา จุฬามณี',
#  '๙กษม ศรี',
#  '๙รรณิการ์ นาค',
#  '8กรสิทธิ์ มาควิบูลย์',
#  '๙มลพร ประยูรยิ้ม',
#  '๙กษม ราษฎร์ประสาทพล์',
#  '๙มลชนก ',
#  'ััลยา ดังอุโคต',
#  '8ระ',
#  'ๆู้',
#  'กรุณา โมรา',
#  '๊กวิทย์ กิตติวิบูลย์',
#  'ฤฤษณะ รักษากิจิ',
#  'ััลยา ลิ้มสวัสดิ์',
#  '๙รรณิการ์ ศิริ',
#  '6กียว วิมล',
#  '!รกฎ คำฟู',
#  'ๆกสุม โมมิน์',
#  '๙ารวี แช่มประ',
#  '๊วี นนทะ',
#  '๊กสินทร์ ',
#  'ๆอบชัย โพชะกร์',
#  'กฤษฎา วงศ์สง่า',
#  '8ายแจ้ แซ่ตั้ง',
#  '๙รรณิการ์ ดำรงวุฒ',
#  '๙กศล การกายัน์',
#  '๙กศกนก ปิ่นปาก์',
#  '8กรียงไกร ',
#  '๙รรณิการ์ กอยสมบัติ',
#  'ๆำจร คำมมู',
#  '๙าญจนาวรรณ ออมสิน์',
#  '๙ก้า หลาบุญ',
#  '8ุล',
#  '๙ัญญา สิงสาหาด์',
#  'กุลภัทร ดาวกระจ่าง์ง',
#  'ฤฤติยา บุษปริก์',
#  'ััลยา แสงงาม',
#  '6กษรา คริดตตแฟ',
#  'ๆำธร หาญสุรินทร์',
#  'การะ',
#  'ๆอบกุล มากพูน',
#  '๙กษณิกา ปัญญาหารน',
#  '๙มลพร โพธินันทะ',
#  'ฤฤษณะ ',
#  'ๆิตติ กมลสันติสุข์',
#  '๙ารไห้',
#  'กฤตวัลย์ ธีระพงษ์ง',
#  '๙มลฉัตร โกมลดิษฐ์',
#  '8ุลวดี ',
#  'ๆิตติกงค์ ',
#  'กรกัญยา ',
#  '8กรรุจ ซี',
#  'กฤษฎา ',
#  '๙ก้วประไพร ',
#  '8ฤษ ',
#  '๙าญจนา พวงมณีี',
#  '๙กศรา ',
#  '๙านต์ อัครวิวัฒน์์',
#  'ๆิมไล้ ชาคริม',
#  '8ุลศักดิ์ อยู่สุข์',
#  '๙กวิทย์ ศิลานนท์',
#  '๙าญจนา สมัครราช์์',
#  '๙านดา รังสิมะวงศ์ง',
#  'ฤกษ์ แสงสระคุ',
#  '!ฤษ',
#  '6กตุ',
#  '๙กษณี ต้นภักดี',
#  '8กรสีห์ แสงสวาสิ์',
#  '๙ิตติ ',
#  '8ระบี๋ สุขสัตจี',
#  '๙นกศักดิ์ สุวรรณชื่น',
#  '๙กทิติ จำ',
#  '๙ันทิมา ทัศกลิ่น',
#  '8กรียงไกร สุรินตา์',
#  'การีม โพธิ์ทอง',
#  '๙าญจนา กันทะ',
#  'ๆิมไล้ ศรีกิจกูล',
#  '6กษร หวานแก้ว',
#  '๙มลรัตน์ กมลพิมาน์',
#  'กระจ่าง ',
#  '6กื้อกูล บุญ',
#  '8กรทอง ช้างน้อย',
#  '๙กณิกา คุนจันทร์',
#  '๙กวิทย์ ',
#  'ๆอบแก้ว ',
#  '๙ิตติยา น้อยสินุ์',
#  'ๆ้อง',
#  '๙ิตติพร พิมพ์สวัสดิ์',
#  '๙าหลง ดีมี',
#  '๙นกวรรณ สุขสมจิตร',
#  '8ฤตยวัฒน์ ชัยรัตน์',
#  'ๆกมล นิลวง',
#  '๙ก่า',
#  'ๆำธร สมุทรสินุ์',
#  '6ีรติ ',
#  'ๆองกฎ สุขประ',
#  '6กศินี สุหัสปรีชา',
#  'กติกา มูลโพธิ์์',
#  '6กษร บัวทอง',
#  'ฤฤษณะ หังแก้ว',
#  '8กรียง',
#  '8กรียงไกร สุขแจ่ม',
#  '๙มล บุญยะพคาค้า',
#  '๙มล ',
#  'ซืนอี',
#  'กรสุข ชีนถนาวรรย์',
#  '๙าญจนา ยอดฉิมมา',
#  '๙ิตติมา ',
#  'องกิน',
#  'ๆิตติ ',
#  '๙รรณิการ์ บัวบึงงาม',
#  'ๆิ่งดาว ซอนบุญลา',
#  '6กษร แสงทองง',
#  'ััลยา พันธ์สวัสดิ์',
#  '๙มล ',
#  'ฤฤษณะ หลักคำ',
#  'ๆำพล ชัยจำรัส์',
#  '๙ิตติพิช วาดน้อย',
#  'ฤฤษณะ อยู่',
#  '๙ัญญาณัฐ อมร',
#  '๙นกกาญจน์ ไม้อ่อนน',
#  '๙าญจนา ฉิมพาลี',
#  'ๆู้',
#  'กนิษฐา ปาวะบุตร',
#  '๙าญจนา วันจิต์',
#  '6กษร สี',
#  '๙ารท้อนยาติ',
#  '๙ารมูนแบบฝร',
#  'ๆกมลกล้า แก้วคำภา',
#  'กฤษณะ ',
#  '8ุศล กระแสซินร์',
#  '๙านดา ลิขิตรานันท์',
#  'ฤฤษณะ แสงรอด์',
#  '๙นกรัตน์ สิงห์สมัน์',
#  '8กรียงไกร ขันตี',
#  '๙รรณิการ์ อิฐวัฒน์',
#  '๙นกวรรณ วงศ์สวัสดิ์',
#  '๙นกพร ',
#  '๙ก้ว โกมาสถิตย์์',
#  '8ุหลาบ โตทองง',
#  '๙กษสุดา ',
#  '8กรสี แก้ว',
#  '๙านต์ชนก ',
#  '๙นกกฎหวาน แซ่',
#  '๙มลพร จันทร์โปร่ง',
#  '๙กวิทย์ นิลาภัยจิตร',
#  '๙ารอุทิศ์',
#  '6ชกร อัศมาศ์์ต',
#  '๙านต์ สุขสมทัย',
#  '๙านดา สุขสมบูรณ์',
#  'ััลยกร ศรใจ',
#  'ััลยา ใจกว้าง',
#  '8รองทอง แซ่ตั้ง',
#  '๙ันยารัตน์ พิมพ์ศิริ์',
#  '๙กษณี ',
#  '8ุหลาบ บัว',
#  '๙รรณิการ์ มอญคำ',
#  '8ลีบ ขุนตอ',
#  '๙กวิท ',
#  '6กษลิน แก้วโกมล',
#  'ๆกสุม บัน',
#  '๙าญจนา คำสุ',
#  '๙ก้ว ',
#  'กัลยา มุริโชน์',
#  '๙รรณิการ์ วงศ์สอน',
#  '๙าญจนา ดวงตา',
#  '๙กษม แคนไธสง์งงง',
#  'ๆร บวรกิจรุงงรส์',
#  'ททพาวัฒนาสุข์',
#  'ๆิจจา สมสวัสดิ์์',
#  '8กรียงศักดิ์ ยอดยืน',
#  'ๆังสดาล หุ่นแสน',
#  'กรวรรณ ชีคะตา',
#  'กรุณา ',
#  '๙าหลง ',
#  '๙มลชนก ยืนยงง',
#  'กุลวดี ศรีวิไล',
#  ...]

# %%
with open('25ep-pred.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(pred))

# %%
with open('ground_truth.txt','w',encoding='utf-8') as f:
    f.write('\n'.join(test_target_texts))
